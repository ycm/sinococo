# %%
import pickle as pkl
import pandas as pd
import numpy as np
import unicodedata as unic
from collections import defaultdict

# %%
with open('BINOMES_FULL_LIST.pkl', 'rb') as f:
    binomes_full_list = pkl.load(f)
with open('BINOMES_PARSED_LIST.pkl', 'rb') as f:
    binomes_parsed_list = pkl.load(f)
with open('BINOMES_PARSED_SAME_DS.pkl', 'rb') as f:
    binomes_parsed_same_ds = pkl.load(f)

# %%
# for st in binomes_parsed_same_ds.itersets():
#     if len(st) > 1:
#         print(st)

# %%
pinyins = set()
with open('pinyin_table.csv') as f:
    for line in f:
        ln = [entry for entry in line.strip().split(',') if entry]
        for entry in ln:
            pinyins.add(unic.normalize('NFC', ''.join([c for c in entry if c.isalpha()])))
pinyins.add('er')

# %%
def remove_tone_mark(pinyin_syllable):
    return ''.join([c for c in unic.normalize('NFD', pinyin_syllable) if c.isalpha()])

# %%
def change_to_numerals(pinyin_syllable):
    no_tone = remove_tone_mark(pinyin_syllable)
    non_alpha = [c for c in unic.normalize('NFD', pinyin_syllable) if not c.isalpha()]
    if "ā"[1] in non_alpha:
        return no_tone + '1'
    if "é"[1] in non_alpha:
        return no_tone + '2'
    if "ǒ"[1] in non_alpha:
        return no_tone + '3'
    if "ò"[1] in non_alpha:
        return no_tone + '4'

# %%
clusters = []
for st in binomes_parsed_same_ds.itersets():
    st_with_numbers = set()
    for (binome, pron) in st:
        if len(binome) != 2:
            continue
        pron_composed = unic.normalize('NFC', pron)
        valid_splits = []
        for i in range(1, len(pron_composed)):
            first, second = pron_composed[:i], pron_composed[i:]
            if remove_tone_mark(first) in pinyins and remove_tone_mark(second) in pinyins:
                valid_splits.append((first, second))
        if len(valid_splits) == 1:
            st_with_numbers.add((binome, change_to_numerals(valid_splits[0][0]), change_to_numerals(valid_splits[0][1])))
        elif "'" in pron_composed:
            first, second = pron_composed.split("'")
            st_with_numbers.add((binome, change_to_numerals(first), change_to_numerals(second)))
        elif "`" in pron_composed:
            first, second = pron_composed.split("`")
            st_with_numbers.add((binome, change_to_numerals(first), change_to_numerals(second)))
        elif "’" in pron_composed:
            first, second = pron_composed.split("’")
            st_with_numbers.add((binome, change_to_numerals(first), change_to_numerals(second)))
        else:
            print(binome, pron)
    if st_with_numbers:
        clusters.append(st_with_numbers)
# Out:
# 芍藥 zhuólüè
# 勺藥 zhuólüè
# 鸜鵒 qú

# %%
clusters
# Out:
# [{('俾倪', 'pi4', 'ni4'), ('俾睨', 'pi4', 'ni4'), ('埤坭', 'pi4', 'ni4')},
#  {('篳篥', 'bi4', 'li4'), ('觱篥', 'bi4', 'li4')},
#  {('倉庚', 'cang1', 'geng1'), ('鶬鶊', 'cang1', 'geng1')},
#  {('孱顏', 'chan2', 'yan2'), ('巉巖', 'chan2', 'yan2')},
#  {('硨磲', 'ju1', 'qu2'), ('車渠', 'ju1', 'qu2')},
#  {('岨峿', 'ju3', 'yu3'), ('鉏鋙', 'ju3', 'yu3'), ('齟齬', 'ju3', 'yu3')},
#  {('蹢躅', 'zhi2', 'zhu2'), ('躑躅', 'zhi2', 'zhu2')},
#  {('毒冒', 'dai4', 'mao4'), ('瑇瑁', 'dai4', 'mao4')},
#  {('仿佛', 'fang3', 'fu2'), ('彷彿', 'fang3', 'fu2')},
#  {('仿偟', 'pang2', 'huang2'),
#   ('傍偟', 'pang2', 'huang2'),
#   ('彷徨', 'pang2', 'huang2'),
#   ('徬徨', 'pang2', 'huang2'),
#   ('房皇', 'pang2', 'huang2')},
#  {('氤氳', 'yin1', 'yun1'),
#   ('絪縕', 'yin1', 'yun1'),
#   ('茵蒀', 'yin1', 'yun1'),
#   ('葐蒀', 'fen2', 'yun1')},
#  {('匍匐', 'pu2', 'fu2'),
#   ('扶伏', 'pu2', 'fu2'),
#   ('蒲伏', 'pu2', 'fu2'),
#   ('蒲服', 'pu2', 'fu2')},
#  {('浩汗', 'hao4', 'han4'), ('滈汗', 'hao4', 'han4')},
#  {('澒洞', 'hong4', 'dong4'), ('虹洞', 'hong4', 'dong4')},
#  {('怳惚', 'huang3', 'hu1'),
#   ('恍忽', 'huang3', 'hu1'),
#   ('恍惚', 'huang3', 'hu1'),
#   ('慌惚', 'huang3', 'hu1'),
#   ('芒忽', 'huang3', 'hu1'),
#   ('荒忽', 'huang1', 'hu1')},
#  {('迦逅', 'xie4', 'hou4'), ('邂逅', 'xie4', 'hou4')},
#  {('摎蓼', 'jiu1', 'liu3'), ('糾蓼', 'jiao3', 'liao3')},
#  {('君遷', 'jun1', 'qian1'), ('桾櫏', 'jun1', 'qian1')},
#  {('坎坷', 'kan3', 'ke3'), ('轗軻', 'kan3', 'ke3')},
#  {('崑崙', 'kun1', 'lun2'), ('昆侖', 'kun1', 'lun2')},
#  {('昆侖', 'hun2', 'lun2'), ('渾淪', 'hun2', 'lun2')},
#  {('昆吾', 'kun1', 'wu2'), ('琨珸', 'kun1', 'wu2')},
#  {('藍縷', 'lan2', 'lu3'), ('襤縷', 'lan2', 'lu3'), ('襤褸', 'lan2', 'lu3')},
#  {('蘺褷', 'li2', 'shi1'), ('離褷', 'li2', 'shi1')},
#  {('苓落', 'ling2', 'luo4'), ('零落', 'ling2', 'luo4')},
#  {('瑪瑙', 'ma3', 'nao3'), ('馬腦', 'ma3', 'nao3')},
#  {('僶俛', 'min3', 'mian3'), ('僶勉', 'min3', 'mian3'), ('閔勉', 'min3', 'mian3')},
#  {('茗艼', 'ming2', 'ting1'), ('酩酊', 'ming3', 'ding3')},
#  {('兠鍪', 'dou1', 'mou2'), ('兠鞪', 'dou1', 'mou2')},
#  {('椅柅', 'yi3', 'ni3'), ('猗狔', 'yi3', 'ni3')},
#  {('杌隉', 'wu4', 'nie4'), ('臲卼', 'nie4', 'wu4'), ('阢隉', 'wu4', 'nie4')},
#  {('婆娑', 'po2', 'suo1'), ('媻娑', 'po2', 'suo1')},
#  {('咆哮', 'pao2', 'xiao1'), ('炰烋', 'pao2', 'xiao1')},
#  {('徘徊', 'pai2', 'huai2'), ('裴徊', 'pei2', 'huai2')},
#  {('埤堄', 'pi4', 'ni4'), ('睥睨', 'pi4', 'ni4')},
#  {('僛丑', 'qi1', 'chou3'), ('魌丑', 'qi1', 'chou3')},
#  {('籧篨', 'qu2', 'chu2'), ('蘧蒢', 'qu2', 'chu2')},
#  {('劬錄', 'qu2', 'lu4'), ('軥錄', 'qu2', 'lu4')},
#  {('鴝鵒', 'qu2', 'yu4'), ('鸜鵒', 'qu2', 'yu4')},
#  {('茹蘆', 'ru2', 'lu2'), ('蕠蘆', 'ru2', 'lu2')},
#  {('舑舕', 'tan1', 'tan4'), ('舔舕', 'tian3', 'tan4')},
#  {('唐突', 'tang2', 'tu1'), ('樘突', 'tang2', 'tu1')},
#  {('姚冶', 'yao2', 'ye3'), ('窕冶', 'yao2', 'ye3')},
#  {('滂陀', 'pang1', 'tuo2'), ('滂陁', 'pang1', 'tuo2')},
#  {('汪漾', 'wang1', 'yang4'), ('瀇漾', 'wang3', 'yang4')},
#  {('罔閬', 'wang3', 'liang3'), ('魍魎', 'wang3', 'liang3')},
#  {('握齱', 'wo4', 'chuo4'), ('齷齱', 'wo4', 'chuo4')},
#  {('孅趨', 'qian1', 'qu1'), ('纖趨', 'xian1', 'qu1')},
#  {('䆗窱', 'yao3', 'tiao3'), ('窈窕', 'yao3', 'tiao3')},
#  {('慇勤', 'yin1', 'qin2'), ('慇懃', 'yin1', 'qin2'), ('殷勤', 'yin1', 'qin2')},
#  {('招搖', 'shao2', 'yao2'), ('逍遙', 'xiao1', 'yao2')},
#  {('侜張', 'zhou1', 'zhang1'), ('譸張', 'zhou1', 'zhang1')},
#  {('侏儒', 'zhu1', 'ru2'), ('朱儒', 'zhu1', 'ru2')},
#  {('倉卒', 'cang1', 'cu4'), ('倉猝', 'cang1', 'cu4')},
#  {('蟕蠵', 'zui1', 'xi1'), ('觜蠵', 'zi1', 'xi1')},
#  {('靉靆', 'ai4', 'dai4')},
#  {('靉靅', 'ai4', 'pei4')},
#  {('倉煌', 'cang1', 'huang2'), ('倉皇', 'cang1', 'huang2')},
#  {('嶒峵', 'ceng2', 'rong2')},
#  {('崚嶒', 'ling2', 'ceng2')},
#  {('蠆介', 'chai4', 'jie4'), ('蠆芥', 'chai4', 'jie4')},
#  {('蟬聯', 'chan2', 'lian2'), ('蟬連', 'chan2', 'lian2')},
#  {('猖獗', 'chang1', 'jue2'), ('猖蹶', 'chang1', 'jue2')},
#  {('綝纚', 'shen1', 'xi3')},
#  {('綝縿', 'shen1', 'shan1')},
#  {('躕躇', 'chu2', 'chu2')},
#  {('踟躕', 'chi2', 'chu2')},
#  {('葱蘢', 'cong1', 'long3')},
#  {('蘢葱', 'long3', 'cong1')},
#  {('綷縩', 'cui4', 'cai4')},
#  {('綷粲', 'cui4', 'can4')},
#  {('蝴蝶', 'hu2', 'die2')},
#  {('蛺蝶', 'jia2', 'die2')},
#  {('跌宕', 'die1', 'dang4'), ('跌蕩', 'die1', 'dang4')},
#  {('娥媓', 'e2', 'huang2'), ('娥皇', 'e2', 'huang2')},
#  {('恆娥', 'heng2', 'e2')},
#  {('嫦娥', 'chang2', 'e2')},
#  {('婀娜', 'e1', 'nuo3')},
#  {('娜婀', 'nuo3', 'e1')},
#  {('放浪', 'fang4', 'lang2')},
#  {('放蕩', 'fang4', 'dang4')},
#  {('放意', 'fang4', 'yi4')},
#  {('岪鬱', 'fu2', 'yu4')},
#  {('鬱岪', 'yu4', 'fu2')},
#  {('芙蓉', 'fu2', 'rong2'), ('芙蕖', 'fu2', 'qu2')},
#  {('菡萏', 'han4', 'dan4')},
#  {('蘆菔', 'lu2', 'fu2')},
#  {('萊菔', 'lai2', 'fu2')},
#  {('蘿菔', 'luo2', 'fu2')},
#  {('鈷䥈', 'gu3', 'mu3'), ('鈷鉧', 'gu3', 'mu3')},
#  {('惚怳', 'hu1', 'huang3'), ('惚恍', 'hu1', 'huang3')},
#  {('滉瀁', 'huang4', 'yang3')},
#  {('捷給', 'jie2', 'ji3')},
#  {('捷急', 'jie2', 'ji2')},
#  {('桔梗', 'jie2', 'geng3')},
#  {('山桔', 'shan1', 'jie2')},
#  {('金橘', 'jin1', 'ju2')},
#  {('金柑', 'jin1', 'gan1')},
#  {('蜻蜒', 'qing1', 'yan2')},
#  {('蜻蛉', 'qing1', 'ling2')},
#  {('盧橘', 'lu2', 'ju2')},
#  {('苴蒪', 'ju1', 'po4')},
#  {('蒪苴', 'po4', 'ju1')},
#  {('蘘荷', 'rang2', 'he2')},
#  {('駏驉', 'ju4', 'xu1')},
#  {('嬋娟', 'chan2', 'juan1')},
#  {('㛹娟', 'pian2', 'juan1')},
#  {('㝩㝗', 'kang1', 'lang2')},
#  {('㝩梁', 'kang1', 'liang2')},
#  {('孔雀', 'kong3', 'que4')},
#  {('孔翠', 'kong3', 'cui4')},
#  {('荳蔻', 'dou4', 'kou4'), ('豆蔻', 'dou4', 'kou4')},
#  {('斕斑', 'lan2', 'ban1'), ('斕斒', 'lan2', 'ban1')},
#  {('斒斕', 'ban1', 'lan2')},
#  {('檳榔', 'bin1', 'lang2')},
#  {('桄榔', 'guang1', 'lang2')},
#  {('儻朗', 'tang3', 'lang3'),
#   ('儻閬', 'tang3', 'lang3'),
#   ('爣朗', 'tang3', 'lang3'),
#   ('爣閬', 'tang3', 'lang3')},
#  {('荔支', 'li4', 'zhi1'), ('荔枝', 'li4', 'zhi1')},
#  {('褵褷', 'li2', 'shi1')},
#  {('褷褵', 'shi1', 'li2')},
#  {('邐迤', 'li3', 'yi3')},
#  {('迤邐', 'yi3', 'li3')},
#  {('俍倡', 'lang3', 'chang1')},
#  {('俍傍', 'lang3', 'pang2')},
#  {('踉蹌', 'liang4', 'qiang1'), ('踉蹡', 'liang4', 'qiang1')},
#  {('伶俜', 'ling2', 'ping1')},
#  {('俜伶', 'ping1', 'ling2')},
#  {('㱥殑', 'ling2', 'qing2')},
#  {('殑㱥', 'qing2', 'ling2')},
#  {('沙鰡', 'sha1', 'liu4'), ('紗鰡', 'sha1', 'liu4')},
#  {('瓏玲', 'long2', 'ling2')},
#  {('玲瓏', 'ling2', 'long2')},
#  {('瓏璁', 'long2', 'cong1')},
#  {('蘢茸', 'long3', 'rong2')},
#  {('蘿勒', 'luo2', 'le4'), ('蘿艻', 'luo2', 'le4')},
#  {('蛤蟆', 'ha2', 'ma2'), ('蝦蟆', 'ha2', 'ma2')},
#  {('濛澒', 'meng2', 'hong4')},
#  {('澒濛', 'hong4', 'meng2')},
#  {('艨艟', 'meng2', 'chong1'), ('艨衝', 'meng2', 'chong1')},
#  {('蠓蠛', 'meng3', 'mie4')},
#  {('蠛蠓', 'mie4', 'meng3')},
#  {('渺茫', 'miao3', 'mang2')},
#  {('渺漫', 'miao3', 'man4')},
#  {('渺瀰', 'miao3', 'mi2')},
#  {('溟涬', 'ming3', 'xing4')},
#  {('涬溟', 'xing4', 'ming3')},
#  {('莫錯', 'mo4', 'cuo4')},
#  {('錯莫', 'cuo4', 'mo4')},
#  {('葩華', 'pa1', 'hua2')},
#  {('紛葩', 'fen1', 'pa1')},
#  {('滂湃', 'peng1', 'pai4'), ('澎湃', 'peng1', 'pai4')},
#  {('叛衍', 'pan4', 'yan3')},
#  {('叛換', 'pan4', 'huan4')},
#  {('媻姍', 'pan2', 'shan1'), ('媻珊', 'pan2', 'shan1')},
#  {('磐桓', 'pan2', 'huan2')},
#  {('磐辟', 'pan2', 'bi4')},
#  {('蹣跚', 'pan2', 'shan1')},
#  {('蹣連', 'pan2', 'lian2')},
#  {('蹣辟', 'pan2', 'bi4')},
#  {('磅礡', 'pang2', 'bo2')},
#  {('磅唐', 'pang2', 'tang2')},
#  {('蓬勃', 'peng2', 'bo2')},
#  {('蓬茸', 'peng2', 'rong2')},
#  {('戚促', 'qi1', 'cu4')},
#  {('戚草', 'qi1', 'cao3')},
#  {('苒荏', 'ran3', 'ren3')},
#  {('荏苒', 'ren3', 'ran3')},
#  {('萎蕤', 'wei3', 'rui2'), ('葳蕤', 'wei3', 'rui2')},
#  {('瑟索', 'se4', 'suo3')},
#  {('瑟縮', 'se4', 'suo3')},
#  {('僧祇', 'seng1', 'qi2'), ('僧耆', 'seng1', 'qi2')},
#  {('舍利', 'she4', 'li4')},
#  {('淰燿', 'shen3', 'shuo4')},
#  {('淰躍', 'shen3', 'yue4')},
#  {('倏忽', 'shu1', 'hu1')},
#  {('倏眒', 'shu1', 'shen1')},
#  {('壇曼', 'dan4', 'man4'), ('壇漫', 'dan4', 'man4')},
#  {('町畽', 'tian3', 'tuan3'), ('町疃', 'tian3', 'tuan3')},
#  {('曈曚', 'tong2', 'meng2')},
#  {('曈曨', 'tong2', 'long2')},
#  {('膧朧', 'tong2', 'long2')},
#  {('膧朦', 'tong2', 'meng2')},
#  {('汍瀾', 'wan2', 'lan2'), ('汍蘭', 'wan2', 'lan2')},
#  {('巇險', 'xi1', 'xian3')},
#  {('險巇', 'xian3', 'xi1')},
#  {('恓惶', 'xi1', 'huang2')},
#  {('恓屑', 'xi1', 'xie4')},
#  {('躞蹀', 'xie4', 'die2')},
#  {('惺忪', 'xing1', 'song1'), ('惺鬆', 'xing1', 'song1')},
#  {('坱圠', 'yang3', 'ya4'), ('坱軋', 'yang3', 'ya4')},
#  {('徜徉', 'chang2', 'yang2')},
#  {('彷徉', 'pang2', 'yang2')},
#  {('望洋', 'wang4', 'yang2')},
#  {('汪洋', 'wang1', 'yang2')},
#  {('勺藥', 'shao2', 'yao4'), ('芍藥', 'shao2', 'yao4')},
#  {('颻颺', 'yao2', 'yang2')},
#  {('飄颻', 'piao1', 'yao2')},
#  {('枒杈', 'ya1', 'cha1')},
#  {('杈枒', 'cha1', 'ya1')},
#  {('猗儺', 'e3', 'nuo2')},
#  {('喑噁', 'yin4', 'wu4')},
#  {('喑嗚', 'yin4', 'wu1')},
#  {('因巡', 'yin1', 'xun2'), ('因循', 'yin1', 'xun2')},
#  {('雍容', 'yong1', 'rong2')},
#  {('三雍', 'san1', 'yong1')},
#  {('優遊', 'you1', 'you2')},
#  {('優柔', 'you1', 'rou2')},
#  {('幼妙', 'yao4', 'miao4'), ('幼眇', 'yao4', 'miao4')},
#  {('邅迍', 'zhan1', 'zhun1')},
#  {('迍邅', 'zhun1', 'zhan1')},
#  {('啁噍', 'zhou1', 'jiao1')},
#  {('啁啾', 'zhou1', 'jiu1')},
#  {('鷦鷯', 'jiao1', 'liao2')},
#  {('蓽撥', 'bi4', 'bo1'), ('蓽茇', 'bi4', 'ba2')},
#  {('憔悴', 'qiao2', 'cui4'),
#   ('憔萃', 'qiao2', 'cui4'),
#   ('憔顇', 'qiao2', 'cui4'),
#   ('蕉悴', 'qiao2', 'cui4'),
#   ('蕉萃', 'qiao2', 'cui4')},
#  {('盤薄', 'pan2', 'bo2'), ('磐礡', 'pan2', 'bo2'), ('磐薄', 'pan2', 'bo2')},
#  {('彯搖', 'piao4', 'yao2'), ('票姚', 'piao4', 'yao2')},
#  {('葡桃', 'pu2', 'tao2'), ('葡萄', 'pu2', 'tao2')},
#  {('芊眠', 'qian1', 'mian2'),
#   ('芊綿', 'qian1', 'mian2'),
#   ('阡眠', 'qian1', 'mian2'),
#   ('阡綿', 'qian1', 'mian2')},
#  {('驌驦', 'su4', 'shuang1'), ('鷫鷞', 'su4', 'shuang1')},
#  {('儴佯', 'xiang1', 'yang2'),
#   ('忀徉', 'xiang1', 'yang2'),
#   ('相羊', 'xiang1', 'yang2')}]

# %%
pron_to_cluster_idx = {}
for idx, st in enumerate(clusters):
    for (binome, first, second) in st:
        pron_to_cluster_idx[(first, second)] = idx

cluster_idx_to_prons = defaultdict(list)
for idx, st in enumerate(clusters):
    for (binome, first, second) in st:
        cluster_idx_to_prons[idx].append((first, second))

# %%
for i in range(221):
    for (first, second) in cluster_idx_to_prons[i]:
        if any(((first, second) in cluster_idx_to_prons[j]) or ((second, first) in cluster_idx_to_prons[j]) for j in range(i)):
            print(i, first, second)
# Out:
# 34 pi4 ni4
# 34 pi4 ni4
# 68 long3 cong1
# 78 nuo3 e1
# 83 yu4 fu2
# 90 hu1 huang3
# 90 hu1 huang3
# 102 po4 ju1
# 113 ban1 lan2
# 118 li2 shi1
# 119 shi1 li2
# 121 yi3 li3
# 126 ping1 ling2
# 128 qing2 ling2
# 131 ling2 long2
# 137 hong4 meng2
# 140 mie4 meng3
# 145 xing4 ming3
# 147 cuo4 mo4
# 156 pan2 shan1
# 158 pan2 bi4
# 166 ren3 ran3
# 169 se4 suo3
# 180 tong2 long2
# 181 tong2 meng2
# 184 xian3 xi1
# 198 cha1 ya1
# 209 zhun1 zhan1

# %%
clusters_manually_cleaned = [{('俾倪', 'pi4', 'ni4'), ('俾睨', 'pi4', 'ni4'), ('埤坭', 'pi4', 'ni4'), ('埤堄', 'pi4', 'ni4'), ('睥睨', 'pi4', 'ni4')},
 {('篳篥', 'bi4', 'li4'), ('觱篥', 'bi4', 'li4')},
 {('倉庚', 'cang1', 'geng1'), ('鶬鶊', 'cang1', 'geng1')},
 {('孱顏', 'chan2', 'yan2'), ('巉巖', 'chan2', 'yan2')},
 {('硨磲', 'ju1', 'qu2'), ('車渠', 'ju1', 'qu2')},
 {('岨峿', 'ju3', 'yu3'), ('鉏鋙', 'ju3', 'yu3'), ('齟齬', 'ju3', 'yu3')},
 {('蹢躅', 'zhi2', 'zhu2'), ('躑躅', 'zhi2', 'zhu2')},
 {('芍藥', 'zhuo2', 'lüe4'), ('勺藥', 'zhuo2', 'lüe4')},
 {('毒冒', 'dai4', 'mao4'), ('瑇瑁', 'dai4', 'mao4')},
 {('仿佛', 'fang3', 'fu2'), ('彷彿', 'fang3', 'fu2')},
 {('仿偟', 'pang2', 'huang2'),
  ('傍偟', 'pang2', 'huang2'),
  ('彷徨', 'pang2', 'huang2'),
  ('徬徨', 'pang2', 'huang2'),
  ('房皇', 'pang2', 'huang2')},
 {('氤氳', 'yin1', 'yun1'),
  ('絪縕', 'yin1', 'yun1'),
  ('茵蒀', 'yin1', 'yun1'),
  ('葐蒀', 'fen2', 'yun1')},
 {('匍匐', 'pu2', 'fu2'),
  ('扶伏', 'pu2', 'fu2'),
  ('蒲伏', 'pu2', 'fu2'),
  ('蒲服', 'pu2', 'fu2')},
 {('浩汗', 'hao4', 'han4'), ('滈汗', 'hao4', 'han4')},
 {('澒洞', 'hong4', 'dong4'), ('虹洞', 'hong4', 'dong4')},
 {('怳惚', 'huang3', 'hu1'),
  ('恍忽', 'huang3', 'hu1'),
  ('恍惚', 'huang3', 'hu1'),
  ('慌惚', 'huang3', 'hu1'),
  ('芒忽', 'huang3', 'hu1'),
  ('荒忽', 'huang1', 'hu1'),
  ('惚怳', 'hu1', 'huang3'),
  ('惚恍', 'hu1', 'huang3')},
 {('迦逅', 'xie4', 'hou4'), ('邂逅', 'xie4', 'hou4')},
 {('摎蓼', 'jiu1', 'liu3'), ('糾蓼', 'jiao3', 'liao3')},
 {('君遷', 'jun1', 'qian1'), ('桾櫏', 'jun1', 'qian1')},
 {('坎坷', 'kan3', 'ke3'), ('轗軻', 'kan3', 'ke3')},
 {('崑崙', 'kun1', 'lun2'), ('昆侖', 'kun1', 'lun2')},
 {('昆侖', 'hun2', 'lun2'), ('渾淪', 'hun2', 'lun2')},
 {('昆吾', 'kun1', 'wu2'), ('琨珸', 'kun1', 'wu2')},
 {('藍縷', 'lan2', 'lu3'), ('襤縷', 'lan2', 'lu3'), ('襤褸', 'lan2', 'lu3')},
 {('蘺褷', 'li2', 'shi1'), ('離褷', 'li2', 'shi1'), ('褵褷', 'li2', 'shi1'), ('褷褵', 'shi1', 'li2')},
 {('苓落', 'ling2', 'luo4'), ('零落', 'ling2', 'luo4')},
 {('瑪瑙', 'ma3', 'nao3'), ('馬腦', 'ma3', 'nao3')},
 {('僶俛', 'min3', 'mian3'), ('僶勉', 'min3', 'mian3'), ('閔勉', 'min3', 'mian3')},
 {('茗艼', 'ming2', 'ting1'), ('酩酊', 'ming3', 'ding3')},
 {('兠鍪', 'dou1', 'mou2'), ('兠鞪', 'dou1', 'mou2')},
 {('椅柅', 'yi3', 'ni3'), ('猗狔', 'yi3', 'ni3')},
 {('杌隉', 'wu4', 'nie4'), ('臲卼', 'nie4', 'wu4'), ('阢隉', 'wu4', 'nie4')},
 {('婆娑', 'po2', 'suo1'), ('媻娑', 'po2', 'suo1')},
 {('咆哮', 'pao2', 'xiao1'), ('炰烋', 'pao2', 'xiao1')},
 {('徘徊', 'pai2', 'huai2'), ('裴徊', 'pei2', 'huai2')},
 {('僛丑', 'qi1', 'chou3'), ('魌丑', 'qi1', 'chou3')},
 {('籧篨', 'qu2', 'chu2'), ('蘧蒢', 'qu2', 'chu2')},
 {('劬錄', 'qu2', 'lu4'), ('軥錄', 'qu2', 'lu4')},
 {('鴝鵒', 'qu2', 'yu4'), ('鸜鵒', 'qu2', 'yu4')},
 {('茹蘆', 'ru2', 'lu2'), ('蕠蘆', 'ru2', 'lu2')},
 {('舑舕', 'tan1', 'tan4'), ('舔舕', 'tian3', 'tan4')},
 {('唐突', 'tang2', 'tu1'), ('樘突', 'tang2', 'tu1')},
 {('姚冶', 'yao2', 'ye3'), ('窕冶', 'yao2', 'ye3')},
 {('滂陀', 'pang1', 'tuo2'), ('滂陁', 'pang1', 'tuo2')},
 {('汪漾', 'wang1', 'yang4'), ('瀇漾', 'wang3', 'yang4')},
 {('罔閬', 'wang3', 'liang3'), ('魍魎', 'wang3', 'liang3')},
 {('握齱', 'wo4', 'chuo4'), ('齷齱', 'wo4', 'chuo4')},
 {('孅趨', 'qian1', 'qu1'), ('纖趨', 'xian1', 'qu1')},
 {('䆗窱', 'yao3', 'tiao3'), ('窈窕', 'yao3', 'tiao3')},
 {('慇勤', 'yin1', 'qin2'), ('慇懃', 'yin1', 'qin2'), ('殷勤', 'yin1', 'qin2')},
 {('招搖', 'shao2', 'yao2'), ('逍遙', 'xiao1', 'yao2')},
 {('侜張', 'zhou1', 'zhang1'), ('譸張', 'zhou1', 'zhang1')},
 {('侏儒', 'zhu1', 'ru2'), ('朱儒', 'zhu1', 'ru2')},
 {('倉卒', 'cang1', 'cu4'), ('倉猝', 'cang1', 'cu4')},
 {('蟕蠵', 'zui1', 'xi1'), ('觜蠵', 'zi1', 'xi1')},
 {('靉靆', 'ai4', 'dai4')},
 {('靉靅', 'ai4', 'pei4')},
 {('倉煌', 'cang1', 'huang2'), ('倉皇', 'cang1', 'huang2')},
 {('嶒峵', 'ceng2', 'rong2')},
 {('崚嶒', 'ling2', 'ceng2')},
 {('蠆介', 'chai4', 'jie4'), ('蠆芥', 'chai4', 'jie4')},
 {('蟬聯', 'chan2', 'lian2'), ('蟬連', 'chan2', 'lian2')},
 {('猖獗', 'chang1', 'jue2'), ('猖蹶', 'chang1', 'jue2')},
 {('綝纚', 'shen1', 'xi3')},
 {('綝縿', 'shen1', 'shan1')},
 {('躕躇', 'chu2', 'chu2')},
 {('踟躕', 'chi2', 'chu2')},
 {('葱蘢', 'cong1', 'long3'), ('蘢葱', 'long3', 'cong1')},
 {('綷縩', 'cui4', 'cai4')},
 {('綷粲', 'cui4', 'can4')},
 {('蝴蝶', 'hu2', 'die2')},
 {('蛺蝶', 'jia2', 'die2')},
 {('跌宕', 'die1', 'dang4'), ('跌蕩', 'die1', 'dang4')},
 {('娥媓', 'e2', 'huang2'), ('娥皇', 'e2', 'huang2')},
 {('恆娥', 'heng2', 'e2')},
 {('嫦娥', 'chang2', 'e2')},
 {('婀娜', 'e1', 'nuo3'), ('娜婀', 'nuo3', 'e1')},
 {('放浪', 'fang4', 'lang2')},
 {('放蕩', 'fang4', 'dang4')},
 {('放意', 'fang4', 'yi4')},
 {('岪鬱', 'fu2', 'yu4'), ('鬱岪', 'yu4', 'fu2')},
 {('芙蓉', 'fu2', 'rong2'), ('芙蕖', 'fu2', 'qu2')},
 {('菡萏', 'han4', 'dan4')},
 {('蘆菔', 'lu2', 'fu2')},
 {('萊菔', 'lai2', 'fu2')},
 {('蘿菔', 'luo2', 'fu2')},
 {('鈷䥈', 'gu3', 'mu3'), ('鈷鉧', 'gu3', 'mu3')},
 {('滉瀁', 'huang4', 'yang3')},
 {('捷給', 'jie2', 'ji3')},
 {('捷急', 'jie2', 'ji2')},
 {('桔梗', 'jie2', 'geng3')},
 {('山桔', 'shan1', 'jie2')},
 {('金橘', 'jin1', 'ju2')},
 {('金柑', 'jin1', 'gan1')},
 {('蜻蜒', 'qing1', 'yan2')},
 {('蜻蛉', 'qing1', 'ling2')},
 {('盧橘', 'lu2', 'ju2')},
 {('苴蒪', 'ju1', 'po4'), ('蒪苴', 'po4', 'ju1')},
 {('蘘荷', 'rang2', 'he2')},
 {('駏驉', 'ju4', 'xu1')},
 {('嬋娟', 'chan2', 'juan1')},
 {('㛹娟', 'pian2', 'juan1')},
 {('㝩㝗', 'kang1', 'lang2')},
 {('㝩梁', 'kang1', 'liang2')},
 {('孔雀', 'kong3', 'que4')},
 {('孔翠', 'kong3', 'cui4')},
 {('荳蔻', 'dou4', 'kou4'), ('豆蔻', 'dou4', 'kou4')},
 {('斕斑', 'lan2', 'ban1'), ('斕斒', 'lan2', 'ban1'), ('斒斕', 'ban1', 'lan2')},
 {('檳榔', 'bin1', 'lang2')},
 {('桄榔', 'guang1', 'lang2')},
 {('儻朗', 'tang3', 'lang3'),
  ('儻閬', 'tang3', 'lang3'),
  ('爣朗', 'tang3', 'lang3'),
  ('爣閬', 'tang3', 'lang3')},
 {('荔支', 'li4', 'zhi1'), ('荔枝', 'li4', 'zhi1')},
 {('邐迤', 'li3', 'yi3'), ('迤邐', 'yi3', 'li3')},
 {('俍倡', 'lang3', 'chang1')},
 {('俍傍', 'lang3', 'pang2')},
 {('踉蹌', 'liang4', 'qiang1'), ('踉蹡', 'liang4', 'qiang1')},
 {('伶俜', 'ling2', 'ping1'), ('俜伶', 'ping1', 'ling2')},
 {('㱥殑', 'ling2', 'qing2'), ('殑㱥', 'qing2', 'ling2')},
 {('沙鰡', 'sha1', 'liu4'), ('紗鰡', 'sha1', 'liu4')},
 {('瓏玲', 'long2', 'ling2'), ('玲瓏', 'ling2', 'long2')},
 {('瓏璁', 'long2', 'cong1')},
 {('蘢茸', 'long3', 'rong2')},
 {('蘿勒', 'luo2', 'le4'), ('蘿艻', 'luo2', 'le4')},
 {('蛤蟆', 'ha2', 'ma2'), ('蝦蟆', 'ha2', 'ma2')},
 {('濛澒', 'meng2', 'hong4'), ('澒濛', 'hong4', 'meng2')},
 {('艨艟', 'meng2', 'chong1'), ('艨衝', 'meng2', 'chong1')},
 {('蠓蠛', 'meng3', 'mie4'), ('蠛蠓', 'mie4', 'meng3')},
 {('渺茫', 'miao3', 'mang2')},
 {('渺漫', 'miao3', 'man4')},
 {('渺瀰', 'miao3', 'mi2')},
 {('溟涬', 'ming3', 'xing4'), ('涬溟', 'xing4', 'ming3')},
 {('莫錯', 'mo4', 'cuo4'), ('錯莫', 'cuo4', 'mo4')},
 {('葩華', 'pa1', 'hua2')},
 {('紛葩', 'fen1', 'pa1')},
 {('滂湃', 'peng1', 'pai4'), ('澎湃', 'peng1', 'pai4')},
 {('叛衍', 'pan4', 'yan3')},
 {('叛換', 'pan4', 'huan4')},
 {('媻姍', 'pan2', 'shan1'), ('媻珊', 'pan2', 'shan1'), ('蹣跚', 'pan2', 'shan1')},
 {('磐桓', 'pan2', 'huan2')},
 {('磐辟', 'pan2', 'bi4'), ('蹣辟', 'pan2', 'bi4')},
 {('蹣連', 'pan2', 'lian2')},
 {('磅礡', 'pang2', 'bo2')},
 {('磅唐', 'pang2', 'tang2')},
 {('蓬勃', 'peng2', 'bo2')},
 {('蓬茸', 'peng2', 'rong2')},
 {('戚促', 'qi1', 'cu4')},
 {('戚草', 'qi1', 'cao3')},
 {('苒荏', 'ran3', 'ren3'), ('荏苒', 'ren3', 'ran3')},
 {('萎蕤', 'wei3', 'rui2'), ('葳蕤', 'wei3', 'rui2')},
 {('瑟索', 'se4', 'suo3'), ('瑟縮', 'se4', 'suo3')},
 {('僧祇', 'seng1', 'qi2'), ('僧耆', 'seng1', 'qi2')},
 {('舍利', 'she4', 'li4')},
 {('淰燿', 'shen3', 'shuo4')},
 {('淰躍', 'shen3', 'yue4')},
 {('倏忽', 'shu1', 'hu1')},
 {('倏眒', 'shu1', 'shen1')},
 {('壇曼', 'dan4', 'man4'), ('壇漫', 'dan4', 'man4')},
 {('町畽', 'tian3', 'tuan3'), ('町疃', 'tian3', 'tuan3')},
 {('曈曚', 'tong2', 'meng2'), ('膧朦', 'tong2', 'meng2')},
 {('曈曨', 'tong2', 'long2'), ('膧朧', 'tong2', 'long2')},
 {('汍瀾', 'wan2', 'lan2'), ('汍蘭', 'wan2', 'lan2')},
 {('巇險', 'xi1', 'xian3'), ('險巇', 'xian3', 'xi1')},
 {('恓惶', 'xi1', 'huang2')},
 {('恓屑', 'xi1', 'xie4')},
 {('躞蹀', 'xie4', 'die2')},
 {('惺忪', 'xing1', 'song1'), ('惺鬆', 'xing1', 'song1')},
 {('坱圠', 'yang3', 'ya4'), ('坱軋', 'yang3', 'ya4')},
 {('徜徉', 'chang2', 'yang2')},
 {('彷徉', 'pang2', 'yang2')},
 {('望洋', 'wang4', 'yang2')},
 {('汪洋', 'wang1', 'yang2')},
 {('勺藥', 'shao2', 'yao4'), ('芍藥', 'shao2', 'yao4')},
 {('颻颺', 'yao2', 'yang2')},
 {('飄颻', 'piao1', 'yao2')},
 {('枒杈', 'ya1', 'cha1'), ('杈枒', 'cha1', 'ya1')},
 {('猗儺', 'e3', 'nuo2')},
 {('喑噁', 'yin4', 'wu4')},
 {('喑嗚', 'yin4', 'wu1')},
 {('因巡', 'yin1', 'xun2'), ('因循', 'yin1', 'xun2')},
 {('雍容', 'yong1', 'rong2')},
 {('三雍', 'san1', 'yong1')},
 {('優遊', 'you1', 'you2')},
 {('優柔', 'you1', 'rou2')},
 {('幼妙', 'yao4', 'miao4'), ('幼眇', 'yao4', 'miao4')},
 {('邅迍', 'zhan1', 'zhun1'), ('迍邅', 'zhun1', 'zhan1')},
 {('啁噍', 'zhou1', 'jiao1')},
 {('啁啾', 'zhou1', 'jiu1')},
 {('鷦鷯', 'jiao1', 'liao2')},
 {('蓽撥', 'bi4', 'bo1'), ('蓽茇', 'bi4', 'ba2')},
 {('憔悴', 'qiao2', 'cui4'),
  ('憔萃', 'qiao2', 'cui4'),
  ('憔顇', 'qiao2', 'cui4'),
  ('蕉悴', 'qiao2', 'cui4'),
  ('蕉萃', 'qiao2', 'cui4')},
 {('盤薄', 'pan2', 'bo2'), ('磐礡', 'pan2', 'bo2'), ('磐薄', 'pan2', 'bo2')},
 {('彯搖', 'piao4', 'yao2'), ('票姚', 'piao4', 'yao2')},
 {('葡桃', 'pu2', 'tao2'), ('葡萄', 'pu2', 'tao2')},
 {('芊眠', 'qian1', 'mian2'),
  ('芊綿', 'qian1', 'mian2'),
  ('阡眠', 'qian1', 'mian2'),
  ('阡綿', 'qian1', 'mian2')},
 {('驌驦', 'su4', 'shuang1'), ('鷫鷞', 'su4', 'shuang1')},
 {('儴佯', 'xiang1', 'yang2'),
  ('忀徉', 'xiang1', 'yang2'),
  ('相羊', 'xiang1', 'yang2')}]

# %%
cluster_idx_to_prons_cleaned = defaultdict(list)
for idx, st in enumerate(clusters_manually_cleaned):
    for (binome, first, second) in st:
        cluster_idx_to_prons_cleaned[idx].append((first, second))

for i in range(221):
    for (first, second) in cluster_idx_to_prons_cleaned[i]:
        if any(((first, second) in cluster_idx_to_prons_cleaned[j]) or ((second, first) in cluster_idx_to_prons_cleaned[j]) for j in range(i)):
            print(i, first, second)

# %%
CLUSTERS_PARSED = [{y for y in x} for x in clusters_manually_cleaned]

# %% [markdown]
# # merge with CHIDEOD

# %%
binomes_df = pd.read_csv('binomes_df.tsv', sep='\t')

# %%
len(binomes_df)
# Out:
# 927

# %%
for i, row in binomes_df.iterrows():
    traditional, pinyin_tonenumber, orthographic_variants = row
    first, second = pinyin_tonenumber.split('~')
    
    found_idx_in_CLUSTER = None
    
    for i, cluster in enumerate(CLUSTERS_PARSED):
        if any(traditional == binome_ for (binome_, first_, second_) in cluster):
            found_idx_in_CLUSTER = i
            break
#     if not found_idx_in_CLUSTER:
#         for i, cluster in enumerate(CLUSTERS_PARSED):
#             if any((first == first_ and second_ == second_) or (second_ == first and first_ == second) for (binome_, first_, second_) in cluster):
#                 found_idx_in_CLUSTER = i
#                 break

    if found_idx_in_CLUSTER and found_idx_in_CLUSTER >= 0:
        if traditional[1] != '然' and traditional[0] != traditional[1]:
            CLUSTERS_PARSED[found_idx_in_CLUSTER].add((traditional, first, second))
    else:
        if traditional[1] != '然' and traditional[0] != traditional[1]:
            CLUSTERS_PARSED.append({(traditional, first, second)})
            found_idx_in_CLUSTER = -1
            print('added', traditional)
    if found_idx_in_CLUSTER and str(orthographic_variants) != 'nan':
        for variant in orthographic_variants.strip().replace(' ', '').split(','):
            if variant[1] != '然' and variant[0] != variant[1]:
                CLUSTERS_PARSED[found_idx_in_CLUSTER].add((variant, first, second))
# Out:
# added 欸乃
# added 薆薱
# added 啽囈
# added 啽哢
# added 啽默
# added 黯慘
# added 黯黮
# added 案衍
# added 昂藏
# added 囂藹
# added 翱翔
# added 懊憦
# added 懊惱
# added 斑剝
# added 苯䔿
# added 崩騰
# added 菶茸
# added 逼迸
# added 觱發
# added 觱沸
# added 蔽芾
# added 襞襀
# added 赑屓
# added 辟易
# added 髟鼬
# added 蹩躠
# added 玢豳
# added 繽紛
# added 驞駍
# added 屏營
# added 撥剌
# added 勃窣
# added 布濩
# added 驂驔
# added 參潭
# added 慘悴
# added 燦爛
# added 蒼黃
# added 滄浪
# added 蒼茫
# added 蒼莽
# added 傖獰
# added 藏催
# added 嘈啐
# added 嘈雜
# added 嘈囋
# added 草次
# added 惻愴
# added 參差
# added 岑崟
# added 蹭蹬
# added 查牙
# added 差池
# added 侘傺
# added 瀺灂
# added 蟾蜍
# added 纏綿
# added 澶湉
# added 嬋媛
# added 潺湲
# added 猖狂
# added 敞怳
# added 惝怳
# added 悵望
# added 怊悵
# added 呫囓
# added 趻踔
# added 噌吰
# added 搶攘
# added 彳亍
# added 佁儗
# added 充斥
# added 憧憬
# added 舂容
# added 衝蓯
# added 惆悵
# added 躊躇
# added 愁疾
# added 綢繆
# added 儲與
# added 惴耎
# added 愴怳
# added 炊累
# added 逴躒
# added 綽約
# added 汋約
# added 淖約
# added 茈虒
# added 蔥蘢
# added 從容
# added 叢殘
# added 踧踖
# added 巑岏
# added 攢雜
# added 漼溰
# added 璀璨
# added 璀錯
# added 翠微
# added 蹉跌
# added 蹉跎
# added 嵯峨
# added 駘蕩
# added 澶漫
# added 澹泊
# added 澹淡
# added 澹蕩
# added 淡沱
# added 澹灧
# added 宕冥
# added 碭突
# added 忉怛
# added 燾奡
# added 滴瀝
# added 玓瓑
# added 的皪
# added 稠嶅
# added 嵽嵲
# added 蹀躞
# added 濎濘
# added 飣餖
# added 汀濘
# added 抖擻
# added 憞溷
# added 袢廷
# added 氾瀾
# added 芳菲
# added 沸濆
# added 菲薇
# added 怫愄
# added 沸渭
# added 紛綸
# added 氛氳
# added 芬氳
# added 紛紜
# added 蚡緼
# added 豐茸
# added 扶疏
# added 扶搖
# added 怫鬱
# added 愅詭
# added 梗概
# added 鉤輖
# added 滑稽
# added 姽嫿
# added 詭譎
# added 詭隨
# added 咍台
# added 谽谺
# added 顄淡
# added 汗漫
# added 杭壯
# added 沆漭
# added 沆瀣
# added 號咷
# added 灝溔
# added 輷輘
# added 硡隱
# added 鴻洞
# added 泓宏
# added 泓汯
# added 鴻蒙
# added 港洞
# added 淴泱
# added 萑蔰
# added 萑蘭
# added 奐衍
# added 荒唐
# added 熀爛
# added 晃朗
# added 洸洋
# added 滉漾
# added 揮霍
# added 虺隤
# added 薈蔚
# added 渾沌
# added 豁落
# added 濩落
# added 瓠落
# added 霍繹
# added 佶屈
# added 浹洽
# added 檟楚
# added 間關
# added 洚洞
# added 嬌嬈
# added 嶕嶢
# added 叫條
# added 噭咷
# added 碣磍
# added 拮据
# added 捷獵
# added 巀櫱
# added 詰誳
# added 緊絭
# added 齽齘
# added 噤吟
# added 徑廷
# added 啾嘈
# added 轇轕
# added 啾唧
# added 鞠躬
# added 局促
# added 跼躅
# added 咀嚼
# added 踽僂
# added 痀僂
# added 悁急
# added 屈強
# added 屈橋
# added 矍鑠
# added 愷悌
# added 嵁巖
# added 顑頷
# added 阬衡
# added 慷慨
# added 骯髒
# added 抗髒
# added 㕉匝
# added 嶱嵑
# added 鏗鍧
# added 鏗鏘
# added 悾款
# added 倥侗
# added 崆峒
# added 崆㟅
# added 倥傯
# added 怐愗
# added 溝瞀
# added 區霿
# added 劻勷
# added 俇攘
# added 曠蕩
# added 爌熀
# added 壙埌
# added 懭悢
# added 睽睢
# added 騤瞿
# added 躨跜
# added 磈磊
# added 悃款
# added 菈擸
# added 蘭單
# added 欄杆
# added 爛漫
# added 爁焱
# added 琅當
# added 浶浪
# added 牢落
# added 壘塊
# added 磊砢
# added 磊落
# added 楞層
# added 輘轢
# added 離麋
# added 離靡
# added 離披
# added 栗烈
# added 漣洏
# added 聯娟
# added 謰謱
# added 聯卷
# added 連卷
# added 連軒
# added 漣漪
# added 戀眷
# added 瀲灧
# added 梁昌
# added 寥廓
# added 聊浪
# added 飉濿
# added 嘹唳
# added 飂戾
# added 漻浰
# added 寥唳
# added 寥亮
# added 嘹亮
# added 寥落
# added 繚繞
# added 潦倒
# added 憭慄
# added 列缺
# added 璘班
# added 璘彬
# added 琳瑯
# added 淋灕
# added 惏悷
# added 轔轢
# added 燐亂
# added 嶙峋
# added 躪轢
# added 零丁
# added 輘輷
# added 岺巆
# added 凌歷
# added 凌厲
# added 岺嶙
# added 碐磳
# added 懰慄
# added 流連
# added 瀏亮
# added 留落
# added 䚧觩
# added 蟉虯
# added 隆穹
# added 巃嵸
# added 龍鐘
# added 蘢蔥
# added 趢趗
# added 陸離
# added 陸梁
# added 碌硞
# added 淪落
# added 覶縷
# added 駱漠
# added 樂託
# added 絡繹
# added 麻茶
# added 霡霂
# added 霢霂
# added 漫漶
# added 曼羨
# added 曼衍
# added 茫昧
# added 茫洋
# added 莽蒼
# added 漭漾
# added 酕醄
# added 毷氉
# added 昧莫
# added 尨茸
# added 瞢騰
# added 孟浪
# added 彌漫
# added 瀰漫
# added 迷密
# added 孊密
# added 幎歷
# added 密勿
# added 矊眇
# added 瞑眩
# added 蔑蒙
# added 黽勉
# added 溟漭
# added 茗邈
# added 溟沐
# added 摩何
# added 模糊
# added 撓挑
# added 膩細
# added 裊娜
# added 囁嚅
# added 蘖卼
# added 濘溺
# added 忸怩
# added 嘔啞
# added 嘔軋
# added 爬沙
# added 槃礡
# added 盤桓
# added 泮汗
# added 判換
# added 滂濞
# added 磅礴
# added 旁魄
# added 滂沛
# added 滂沱
# added 泡溲
# added 噴薄
# added 濆薄
# added 輣訇
# added 硼磕
# added 淜湃
# added 澎濞
# added 硼隱
# added 膨脝
# added 髬髵
# added 霹靂
# added 披靡
# added 俾倪
# added 埤坭
# added 睥睨
# added 翩飄
# added 便辟
# added 輣闐
# added 蹁躚
# added 飄搖
# added 嫖姚
# added 縹緲
# added 僄狡
# added 瞥列
# added 瞥裂
# added 潎洌
# added 頻煩
# added 嚬呻
# added 娉婷
# added 淜滂
# added 苹縈
# added 坡坨
# added 陂陀
# added 駊騀
# added 溥漠
# added 葡服
# added 朴簌
# added 棲遲
# added 淒楚
# added 萋斐
# added 㩻䧢
# added 攲缺
# added 崎嶇
# added 崎嶷
# added 碕礒
# added 契闊
# added 磧礫
# added 嵌巖
# added 繾綣
# added 鎗玲
# added 瑲玲
# added 槍欀
# added 愀愴
# added 巧老
# added 踥跌
# added 嶔岑
# added 嶔崎
# added 侵尋
# added 浸潯
# added 浸淫
# added 青熒
# added 丘虛
# added 蜷局
# added 礐硞
# added 逡巡
# added 逡循
# added 姌嫋
# added 苒弱
# added 擾攘
# added 擾弱
# added 溶㵝
# added 容與
# added 嚅唲
# added 颯爽
# added 颯沓
# added 騷搔
# added 騷屑
# added 呻吟
# added 率爾
# added 斯須
# added 搜牢
# added 颼飀
# added 索落
# added 荅焉
# added 沓合
# added 㯓臘
# added 嗒焉
# added 曇欒
# added 憛悇
# added 戃慌
# added 曭朗
# added 曭莽
# added 挑達
# added 叨沓
# added 俶儻
# added 倜儻
# added 惕息
# added 淟涊
# added 迢遞
# added 岧嵽
# added 誂越
# added 餮切
# added 渟瀯
# added 渟濙
# added 濎濙
# added 汀濴
# added 瞳矇
# added 氃氋
# added 突兀
# added 秃兀
# added 悇憛
# added 妥帖
# added 唲嘔
# added 頑鈍
# added 蜿蜒
# added 婉戀
# added 涴演
# added 婉轉
# added 汪翔
# added 瀇瀁
# added 旺相
# added 倭遲
# added 崴嵬
# added 逶迤
# added 萎約
# added 巍峩
# added 萎腇
# added 委蛇
# added 磈硊
# added 蓊茸
# added 蓊鬱
# added 婐㛂
# added 偓促
# added 烏乎
# added 嗚咽
# added 嫵媚
# added 沕潏
# added 沕穆
# added 溪刻
# added 淅瀝
# added 翕赩
# added 肸蠁
# added 棲屑
# added 希夷
# added 謑髁
# added 襲雜
# added 徙倚
# added 屭奰
# added 翕赫
# added 浹渫
# added 睍睆
# added 象罔
# added 澩㺒
# added 蕭灑
# added 瀟瑟
# added 瀟森
# added 蕭蔘
# added 瀟率
# added 蕭肅
# added 瀟索
# added 蕭條
# added 瀟條
# added 蕭閒
# added 庨窌
# added 皛溔
# added 澩灂
# added 頡頏
# added 頡滑
# added 洶湧
# added 歔欷
# added 歘吸
# added 戌削
# added 須臾
# added 姁媮
# added 蓄縮
# added 漩澴
# added 烜爀
# added 眴煥
# added 眩湣
# added 泫沄
# added 菴藹
# added 偃蹇
# added 黶翳
# added 噞喁
# added 焱悠
# added 鞅常
# added 鞅掌
# added 泱漭
# added 泱灢
# added 怏悒
# added 窐寥
# added 么麼
# added 夭矯
# added 妖嬈
# added 妖冶
# added 搖曳
# added 杳眇
# added 揶揄
# added 嶫峨
# added 曵曳
# added 依稀
# added 伊邑
# added 猗歟
# added 伊鬱
# added 依約
# added 夷靡
# added 陁靡
# added 夷猶
# added 迤靡
# added 旖旎
# added 靉霼
# added 蘙薈
# added 熠燿
# added 佚豫
# added 抑鬱
# added 屹崒
# added 愔翳
# added 烟熅
# added 夤緣
# added 嚶喔
# added 熒惑
# added 縈紆
# added 巊冥
# added 悠揚
# added 優游
# added 猶豫
# added 黝糾
# added 蚴虯
# added 紆餘
# added 揄揚
# added 蔚結
# added 燠煜
# added 雜錯
# added 雜遝
# added 雜襲
# added 造次
# added 砟硌
# added 咤沙
# added 占斷
# added 輾轉
# added 展轉
# added 啁哳
# added 斟酌
# added 鬇鬡
# added 崢嶸
# added 征營
# added 鄭重
# added 咫尺
# added 踶跂
# added 忪懞
# added 輈張
# added 卓犖
# added 咨嗟
# added 趑趄
# added 嵫釐
# added 恣睢
# added 齱齵
# added 崒兀
# added 蕞爾
# added 岞崿

# %%
CLUSTERS_PARSED
# Out:
# [{('俾倪', 'pi4', 'ni4'),
#   ('俾睨', 'pi4', 'ni4'),
#   ('埤坭', 'pi4', 'ni4'),
#   ('埤堄', 'pi4', 'ni4'),
#   ('睥睨', 'pi4', 'ni4')},
#  {('篳篥', 'bi4', 'li4'), ('觱篥', 'bi4', 'li4')},
#  {('倉庚', 'cang1', 'geng1'), ('鶬鶊', 'cang1', 'geng1')},
#  {('孱顏', 'chan2', 'yan2'),
#   ('嶄巖', 'chan2', 'yan2'),
#   ('嶄巗', 'chan2', 'yan2'),
#   ('巉巖', 'chan2', 'yan2')},
#  {('硨磲', 'ju1', 'qu2'), ('車渠', 'ju1', 'qu2')},
#  {('岨峿', 'ju3', 'yu3'), ('鉏鋙', 'ju3', 'yu3'), ('齟齬', 'ju3', 'yu3')},
#  {('蹢躅', 'zhi2', 'zhu2'), ('躑躅', 'zhi2', 'zhu2')},
#  {('勺藥', 'zhuo2', 'lüe4'), ('芍藥', 'zhuo2', 'lüe4')},
#  {('毒冒', 'dai4', 'mao4'), ('瑇瑁', 'dai4', 'mao4')},
#  {('仿佛', 'fang3', 'fu2'), ('彷彿', 'fang3', 'fu2')},
#  {('仿偟', 'pang2', 'huang2'),
#   ('傍偟', 'pang2', 'huang2'),
#   ('彷徨', 'pang2', 'huang2'),
#   ('徬徨', 'pang2', 'huang2'),
#   ('房皇', 'pang2', 'huang2')},
#  {('氤氳', 'yin1', 'yun1'),
#   ('絪縕', 'yin1', 'yun1'),
#   ('茵蒀', 'yin1', 'yun1'),
#   ('葐蒀', 'fen2', 'yun1')},
#  {('匍匐', 'pu2', 'fu2'),
#   ('扶伏', 'pu2', 'fu2'),
#   ('蒲伏', 'pu2', 'fu2'),
#   ('蒲服', 'pu2', 'fu2')},
#  {('浩汗', 'hao4', 'han4'),
#   ('浩瀚', 'hao4', 'han4'),
#   ('滈汗', 'hao4', 'han4'),
#   ('滈瀚', 'hao4', 'han4')},
#  {('澒洞', 'hong4', 'dong4'), ('虹洞', 'hong4', 'dong4')},
#  {('怳惚', 'hu1', 'huang3'),
#   ('怳惚', 'huang3', 'hu1'),
#   ('恍忽', 'huang3', 'hu1'),
#   ('恍惚', 'hu1', 'huang3'),
#   ('恍惚', 'huang3', 'hu1'),
#   ('惚怳', 'hu1', 'huang3'),
#   ('惚恍', 'hu1', 'huang3'),
#   ('慌惚', 'huang3', 'hu1'),
#   ('芒忽', 'hu1', 'huang3'),
#   ('芒忽', 'huang3', 'hu1'),
#   ('荒忽', 'hu1', 'huang3'),
#   ('荒忽', 'huang1', 'hu1')},
#  {('迦逅', 'xie4', 'hou4'), ('邂逅', 'xie4', 'hou4')},
#  {('摎蓼', 'jiao3', 'liao3'),
#   ('摎蓼', 'jiu1', 'liu3'),
#   ('糾蓼', 'jiao3', 'liao3'),
#   ('糾蓼', 'jiu1', 'liu3')},
#  {('君遷', 'jun1', 'qian1'), ('桾櫏', 'jun1', 'qian1')},
#  {('坎坷', 'kan3', 'ke3'), ('坎軻', 'kan3', 'ke3'), ('轗軻', 'kan3', 'ke3')},
#  {('崑崙', 'kun1', 'lun2'),
#   ('昆侖', 'hun2', 'lun2'),
#   ('昆侖', 'kun1', 'lun2'),
#   ('渾淪', 'hun2', 'lun2')},
#  {('昆侖', 'hun2', 'lun2'), ('渾淪', 'hun2', 'lun2')},
#  {('昆吾', 'kun1', 'wu2'), ('琨珸', 'kun1', 'wu2')},
#  {('藍縷', 'lan2', 'lu3'),
#   ('藍縷', 'lan2', 'lü3'),
#   ('藍褸', 'lan2', 'lü3'),
#   ('襤縷', 'lan2', 'lu3'),
#   ('襤褸', 'lan2', 'lu3'),
#   ('襤褸', 'lan2', 'lü3')},
#  {('蘺褷', 'li2', 'shi1'),
#   ('褵褷', 'li2', 'shi1'),
#   ('褵褷', 'shi1', 'li2'),
#   ('褷褵', 'li2', 'shi1'),
#   ('褷褵', 'shi1', 'li2'),
#   ('離褷', 'li2', 'shi1')},
#  {('苓落', 'ling2', 'luo4'), ('零落', 'ling2', 'luo4')},
#  {('瑪瑙', 'ma3', 'nao3'), ('馬腦', 'ma3', 'nao3')},
#  {('僶俛', 'min3', 'mian3'), ('僶勉', 'min3', 'mian3'), ('閔勉', 'min3', 'mian3')},
#  {('茗艼', 'ming2', 'ting1'), ('酩酊', 'ming3', 'ding3')},
#  {('兠鍪', 'dou1', 'mou2'), ('兠鞪', 'dou1', 'mou2')},
#  {('椅柅', 'yi3', 'ni3'), ('猗儺', 'yi3', 'ni3'), ('猗狔', 'yi3', 'ni3')},
#  {('杌隉', 'wu4', 'nie4'),
#   ('臲卼', 'nie4', 'wu4'),
#   ('蘖卼', 'wu4', 'nie4'),
#   ('阢隉', 'wu4', 'nie4')},
#  {('婆娑', 'po2', 'suo1'), ('媻娑', 'po2', 'suo1')},
#  {('咆哮', 'pao1', 'xiao1'),
#   ('咆哮', 'pao2', 'xiao1'),
#   ('炰烋', 'lie4', 'lie4'),
#   ('炰烋', 'pao2', 'xiao1'),
#   ('炰烋', 'pao2', 'xiao2')},
#  {('徘徊', 'pai2', 'huai2'),
#   ('徘徊', 'pei2', 'huai2'),
#   ('裴徊', 'pai2', 'huai2'),
#   ('裴徊', 'pei2', 'huai2')},
#  {('僛丑', 'qi1', 'chou3'), ('魌丑', 'qi1', 'chou3')},
#  {('籧篨', 'qu2', 'chu2'), ('蘧蒢', 'qu2', 'chu2')},
#  {('劬錄', 'qu2', 'lu4'), ('軥錄', 'qu2', 'lu4')},
#  {('鴝鵒', 'qu2', 'yu4'), ('鸜鵒', 'qu2', 'yu4')},
#  {('茹蘆', 'ru2', 'lu2'), ('蕠蘆', 'ru2', 'lu2')},
#  {('舑舕', 'tan1', 'dan4'),
#   ('舑舕', 'tan1', 'tan4'),
#   ('舑舕', 'tian3', 'tan4'),
#   ('舔舕', 'tan1', 'dan4'),
#   ('舔舕', 'tian3', 'tan4')},
#  {('唐突', 'tang2', 'tu1'), ('樘突', 'tang2', 'tu1')},
#  {('姚冶', 'yao2', 'ye3'), ('窕冶', 'yao2', 'ye3')},
#  {('滂陀', 'pang1', 'tuo2'), ('滂陁', 'pang1', 'tuo2')},
#  {('汪洋', 'wang1', 'yang4'),
#   ('汪漾', 'wang1', 'yang4'),
#   ('汪漾', 'wang3', 'yang4'),
#   ('汪翔', 'wang1', 'yang4'),
#   ('瀇漾', 'wang1', 'yang4'),
#   ('瀇漾', 'wang3', 'yang4')},
#  {('罔閬', 'wang3', 'liang3'), ('魍魎', 'wang3', 'liang3')},
#  {('握齱', 'wo4', 'chuo4'), ('齷齪', 'wo4', 'chuo4'), ('齷齱', 'wo4', 'chuo4')},
#  {('孅趨', 'qian1', 'qu1'), ('纖趨', 'xian1', 'qu1')},
#  {('䆗窱', 'yao3', 'tiao3'), ('窈窕', 'yao3', 'tiao3')},
#  {('慇勤', 'yin1', 'qin2'), ('慇懃', 'yin1', 'qin2'), ('殷勤', 'yin1', 'qin2')},
#  {('招搖', 'shao2', 'yao2'),
#   ('招搖', 'xiao1', 'yao2'),
#   ('招搖', 'zhao1', 'yao2'),
#   ('逍遙', 'shao2', 'yao2'),
#   ('逍遙', 'xiao1', 'yao2')},
#  {('侜張', 'zhou1', 'zhang1'), ('譸張', 'zhou1', 'zhang1')},
#  {('侏儒', 'zhu1', 'ru2'), ('朱儒', 'zhu1', 'ru2')},
#  {('倉卒', 'cang1', 'cu4'), ('倉猝', 'cang1', 'cu4')},
#  {('蟕蠵', 'zui1', 'xi1'), ('觜蠵', 'zi1', 'xi1')},
#  {('靉靆', 'ai4', 'dai4')},
#  {('靉靅', 'ai4', 'pei4')},
#  {('倉煌', 'cang1', 'huang2'), ('倉皇', 'cang1', 'huang2')},
#  {('嶒峵', 'ceng2', 'rong2')},
#  {('崚嶒', 'ling2', 'ceng2')},
#  {('蠆介', 'chai4', 'jie4'), ('蠆芥', 'chai4', 'jie4')},
#  {('蟬聯', 'chan2', 'lian2'), ('蟬連', 'chan2', 'lian2')},
#  {('猖獗', 'chang1', 'jue2'), ('猖蹶', 'chang1', 'jue2')},
#  {('綝纚', 'lin2', 'li2'), ('綝纚', 'shen1', 'xi3')},
#  {('綝縿', 'shen1', 'shan1')},
#  {('躕躇', 'chu2', 'chu2')},
#  {('踟躕', 'chi2', 'chu2')},
#  {('葱蘢', 'cong1', 'long3'), ('蘢葱', 'long3', 'cong1')},
#  {('綷縩', 'cui4', 'cai4')},
#  {('綷粲', 'cui4', 'cai4'), ('綷粲', 'cui4', 'can4')},
#  {('蝴蝶', 'hu2', 'die2')},
#  {('蛺蝶', 'jia2', 'die2')},
#  {('跌宕', 'die1', 'dang4'), ('跌蕩', 'die1', 'dang4')},
#  {('娥媓', 'e2', 'huang2'), ('娥皇', 'e2', 'huang2')},
#  {('恆娥', 'heng2', 'e2')},
#  {('嫦娥', 'chang2', 'e2')},
#  {('娜婀', 'e1', 'nuo3'), ('娜婀', 'nuo3', 'e1'), ('婀娜', 'e1', 'nuo3')},
#  {('放浪', 'fang4', 'lang2'), ('放浪', 'fang4', 'lang4')},
#  {('放蕩', 'fang4', 'dang4')},
#  {('放意', 'fang4', 'yi4')},
#  {('岪鬱', 'fu2', 'yu4'), ('茀鬱', 'fu2', 'yu4'), ('鬱岪', 'yu4', 'fu2')},
#  {('芙蓉', 'fu2', 'rong2'), ('芙蕖', 'fu2', 'qu2')},
#  {('菡萏', 'han4', 'dan4')},
#  {('蘆菔', 'lu2', 'fu2')},
#  {('萊菔', 'lai2', 'fu2')},
#  {('蘿菔', 'luo2', 'fu2')},
#  {('鈷䥈', 'gu3', 'mu3'), ('鈷鉧', 'gu3', 'mu3')},
#  {('滉瀁', 'huang4', 'yang3')},
#  {('捷給', 'jie2', 'ji3')},
#  {('捷急', 'jie2', 'ji2')},
#  {('桔梗', 'jie2', 'geng3')},
#  {('山桔', 'shan1', 'jie2')},
#  {('金橘', 'jin1', 'ju2')},
#  {('金柑', 'jin1', 'gan1')},
#  {('蜻蜒', 'qing1', 'yan2')},
#  {('蜻蛉', 'qing1', 'ling2')},
#  {('盧橘', 'lu2', 'ju2')},
#  {('苴蒪', 'ju1', 'po4'), ('蒪苴', 'po4', 'ju1')},
#  {('蘘荷', 'rang2', 'he2')},
#  {('駏驉', 'ju4', 'xu1')},
#  {('嬋娟', 'chan2', 'juan1'), ('蟬娟', 'chan2', 'juan1')},
#  {('㛹娟', 'pian2', 'juan1')},
#  {('㝩㝗', 'kang1', 'lang2')},
#  {('㝩梁', 'kang1', 'liang2')},
#  {('孔雀', 'kong3', 'que4')},
#  {('孔翠', 'kong3', 'cui4')},
#  {('荳蔻', 'dou4', 'kou4'), ('豆蔻', 'dou4', 'kou4')},
#  {('斒斕', 'ban1', 'lan2'), ('斕斑', 'lan2', 'ban1'), ('斕斒', 'lan2', 'ban1')},
#  {('檳榔', 'bin1', 'lang2')},
#  {('桄榔', 'guang1', 'lang2')},
#  {('儻朗', 'tang3', 'lang3'),
#   ('儻閬', 'tang3', 'lang3'),
#   ('爣朗', 'tang3', 'lang3'),
#   ('爣閬', 'tang3', 'lang3')},
#  {('荔支', 'li4', 'zhi1'), ('荔枝', 'li4', 'zhi1')},
#  {('迤邐', 'li3', 'yi3'),
#   ('迤邐', 'yi3', 'li3'),
#   ('邐迤', 'li3', 'yi3'),
#   ('邐迤', 'yi3', 'li3')},
#  {('俍倡', 'lang3', 'chang1')},
#  {('俍傍', 'lang3', 'pang2')},
#  {('踉蹌', 'liang4', 'qiang1'), ('踉蹡', 'liang4', 'qiang1')},
#  {('伶俜', 'ling2', 'ping1'),
#   ('俜伶', 'ling2', 'ping1'),
#   ('俜伶', 'ping1', 'ling2')},
#  {('㱥殑', 'ling2', 'qing2'),
#   ('殑㱥', 'ling2', 'qing2'),
#   ('殑㱥', 'qing2', 'ling2')},
#  {('沙鰡', 'sha1', 'liu4'), ('紗鰡', 'sha1', 'liu4')},
#  {('玲瓏', 'ling2', 'long2'), ('瓏玲', 'long2', 'ling2')},
#  {('瓏璁', 'long2', 'cong1')},
#  {('蘢茸', 'long3', 'rong2')},
#  {('蘿勒', 'luo2', 'le4'), ('蘿艻', 'luo2', 'le4')},
#  {('蛤蟆', 'ha2', 'ma2'), ('蝦蟆', 'ha2', 'ma2')},
#  {('澒濛', 'hong4', 'meng2'), ('濛澒', 'meng2', 'hong4')},
#  {('艨艟', 'meng2', 'chong1'), ('艨衝', 'meng2', 'chong1')},
#  {('蠓蠛', 'meng3', 'mie4'), ('蠛蠓', 'mie4', 'meng3')},
#  {('渺茫', 'miao3', 'mang2')},
#  {('渺漫', 'miao3', 'man4')},
#  {('渺瀰', 'miao3', 'mi2')},
#  {('涬溟', 'ming3', 'xing4'),
#   ('涬溟', 'xing4', 'ming2'),
#   ('涬溟', 'xing4', 'ming3'),
#   ('溟涬', 'ming3', 'xing4')},
#  {('莫錯', 'mo4', 'cuo4'), ('錯莫', 'cuo4', 'mo4')},
#  {('葩華', 'pa1', 'hua2')},
#  {('紛葩', 'fen1', 'pa1')},
#  {('滂湃', 'peng1', 'pai4'), ('澎湃', 'peng1', 'pai4'), ('澎湃', 'peng2', 'pai4')},
#  {('叛衍', 'pan4', 'yan3')},
#  {('叛換', 'pan4', 'huan4')},
#  {('媻姍', 'pan2', 'shan1'), ('媻珊', 'pan2', 'shan1'), ('蹣跚', 'pan2', 'shan1')},
#  {('磐桓', 'pan2', 'huan2')},
#  {('媻姍', 'pan2', 'bi4'),
#   ('媻珊', 'pan2', 'bi4'),
#   ('磐辟', 'pan2', 'bi4'),
#   ('蹣辟', 'pan2', 'bi4')},
#  {('媻姍', 'pan2', 'lian2'), ('媻珊', 'pan2', 'lian2'), ('蹣連', 'pan2', 'lian2')},
#  {('磅礡', 'pang2', 'bo2')},
#  {('磅唐', 'pang2', 'tang2'), ('磅礴', 'pang2', 'tang2')},
#  {('蓬勃', 'peng2', 'bo2')},
#  {('蓬茸', 'peng2', 'rong2')},
#  {('戚促', 'qi1', 'cu4'), ('戚草', 'qi1', 'cu4')},
#  {('戚促', 'qi1', 'cao3'), ('戚草', 'qi1', 'cao3')},
#  {('苒荏', 'ran3', 'ren3'),
#   ('苒荏', 'ren3', 'ran3'),
#   ('荏苒', 'ran3', 'ren3'),
#   ('荏苒', 'ren3', 'ran3')},
#  {('萎蕤', 'wei1', 'rui2'),
#   ('萎蕤', 'wei3', 'rui2'),
#   ('葳蕤', 'wei1', 'rui2'),
#   ('葳蕤', 'wei3', 'rui2')},
#  {('瑟索', 'se4', 'suo3'), ('瑟縮', 'se4', 'suo1'), ('瑟縮', 'se4', 'suo3')},
#  {('僧祇', 'seng1', 'qi2'), ('僧耆', 'seng1', 'qi2')},
#  {('舍利', 'she4', 'li4')},
#  {('淰燿', 'shen3', 'shuo4')},
#  {('淰躍', 'shen3', 'yue4')},
#  {('倏忽', 'shu1', 'hu1'), ('儵忽', 'shu1', 'hu1')},
#  {('倏眒', 'shu1', 'shen1')},
#  {('壇曼', 'dan4', 'man4'), ('壇漫', 'dan4', 'man4')},
#  {('町畽', 'tian3', 'tuan3'),
#   ('町畽', 'ting3', 'tuan3'),
#   ('町疃', 'tian3', 'tuan3'),
#   ('町疃', 'ting3', 'tuan3')},
#  {('曈曚', 'tong2', 'meng2'),
#   ('曈曨', 'tong2', 'meng2'),
#   ('膧朦', 'tong2', 'meng2')},
#  {('曈曚', 'tong2', 'long2'),
#   ('曈曨', 'tong2', 'long2'),
#   ('膧䑃', 'tong2', 'long2'),
#   ('膧䑃', 'tong2', 'meng2'),
#   ('膧朧', 'tong2', 'long2'),
#   ('膧朧', 'tong2', 'meng2')},
#  {('汍瀾', 'wan2', 'lan2'), ('汍蘭', 'wan2', 'lan2')},
#  {('巇險', 'xi1', 'xian3'),
#   ('巇險', 'xian3', 'xi1'),
#   ('險巇', 'xi1', 'xian3'),
#   ('險巇', 'xian3', 'xi1')},
#  {('恓屑', 'xi1', 'huang2'),
#   ('恓屑', 'xi1', 'xie4'),
#   ('恓惶', 'xi1', 'huang2'),
#   ('恓惶', 'xi1', 'xie4')},
#  {('恓屑', 'xi1', 'xie4')},
#  {('蹀躞', 'xie4', 'die2'), ('躞蹀', 'xie4', 'die2')},
#  {('惺忪', 'xing1', 'song1'), ('惺鬆', 'xing1', 'song1')},
#  {('坱圠', 'yang3', 'ya4'), ('坱軋', 'yang3', 'ya4')},
#  {('倘佯', 'chang2', 'yang2'),
#   ('倘佯', 'pang2', 'yang2'),
#   ('彷徉', 'chang2', 'yang2'),
#   ('彷徉', 'pang2', 'yang2'),
#   ('徜徉', 'chang2', 'yang2'),
#   ('徜徉', 'pang2', 'yang2')},
#  {('彷徉', 'pang2', 'yang2')},
#  {('望洋', 'wang4', 'yang2'),
#   ('汪洋', 'wang4', 'yang2'),
#   ('汪漾', 'wang4', 'yang2'),
#   ('汪翔', 'wang4', 'yang2')},
#  {('望洋', 'wang1', 'yang2'),
#   ('汪洋', 'wang1', 'yang2'),
#   ('汪漾', 'wang1', 'yang2'),
#   ('汪翔', 'wang1', 'yang2')},
#  {('勺藥', 'shao2', 'yao4'), ('芍藥', 'shao2', 'yao4')},
#  {('颻颺', 'yao2', 'yang2')},
#  {('飄颻', 'piao1', 'yao2')},
#  {('杈枒', 'cha1', 'ya1'),
#   ('杈枒', 'cha1', 'ya2'),
#   ('杈枒', 'ya1', 'cha1'),
#   ('枒杈', 'cha1', 'ya2'),
#   ('枒杈', 'ya1', 'cha1')},
#  {('猗儺', 'e1', 'nuo2'), ('猗儺', 'e3', 'nuo2'), ('猗狔', 'e3', 'nuo2')},
#  {('喑噁', 'yin1', 'wu4'), ('喑噁', 'yin4', 'wu4')},
#  {('喑嗚', 'yin4', 'wu1')},
#  {('因巡', 'yin1', 'xun2'), ('因循', 'yin1', 'xun2')},
#  {('雍容', 'yong1', 'rong2')},
#  {('三雍', 'san1', 'yong1')},
#  {('優柔', 'you1', 'you2'), ('優遊', 'you1', 'you2')},
#  {('優柔', 'you1', 'rou2'), ('優遊', 'you1', 'rou2')},
#  {('幼妙', 'yao4', 'miao4'), ('幼眇', 'yao4', 'miao4')},
#  {('迍邅', 'zhan1', 'zhun1'),
#   ('迍邅', 'zhun1', 'zhan1'),
#   ('邅迍', 'zhan1', 'zhun1'),
#   ('邅迍', 'zhun1', 'zhan1')},
#  {('啁啾', 'zhou1', 'jiao1'), ('啁啾', 'zhou1', 'jiu1'), ('啁噍', 'zhou1', 'jiao1')},
#  {('啁啾', 'zhou1', 'jiao1'), ('啁啾', 'zhou1', 'jiu1'), ('啁噍', 'zhou1', 'jiao1')},
#  {('鷦鷯', 'jiao1', 'liao2')},
#  {('蓽撥', 'bi4', 'bo1'), ('蓽茇', 'bi4', 'ba2')},
#  {('憔悴', 'qiao2', 'cui4'),
#   ('憔萃', 'qiao2', 'cui4'),
#   ('憔顇', 'qiao2', 'cui4'),
#   ('蕉悴', 'qiao2', 'cui4'),
#   ('蕉萃', 'qiao2', 'cui4')},
#  {('盤薄', 'pan2', 'bo2'), ('磐礡', 'pan2', 'bo2'), ('磐薄', 'pan2', 'bo2')},
#  {('彯搖', 'piao4', 'yao2'), ('票姚', 'piao4', 'yao2')},
#  {('葡桃', 'pu2', 'tao2'), ('葡萄', 'pu2', 'tao2')},
#  {('芊眠', 'qian1', 'mian2'),
#   ('芊綿', 'qian1', 'mian2'),
#   ('阡眠', 'qian1', 'mian2'),
#   ('阡綿', 'qian1', 'mian2')},
#  {('驌驦', 'su4', 'shuang1'), ('鷫鷞', 'su4', 'shuang1')},
#  {('儴佯', 'xiang1', 'yang2'),
#   ('忀徉', 'xiang1', 'yang2'),
#   ('相羊', 'xiang1', 'yang2')},
#  {('欸乃', 'ai3', 'nai3')},
#  {('薆薱', 'ai4', 'dui4')},
#  {('啽囈', 'an1', 'yi4')},
#  {('啽哢', 'an2', 'long4')},
#  {('啽默', 'an2', 'mo4')},
#  {('黯慘', 'an4', 'can3')},
#  {('黮䨴', 'an4', 'tan3'),
#   ('黮䨴', 'tan3', 'an4'),
#   ('黮䨴', 'tan3', 'dui4'),
#   ('黮暗', 'an4', 'tan3'),
#   ('黮暗', 'tan3', 'an4'),
#   ('黮暗', 'tan3', 'dui4'),
#   ('黯黮', 'an4', 'tan3'),
#   ('黯黮', 'tan3', 'an4'),
#   ('黯黮', 'tan3', 'dui4')},
#  {('案衍', 'an4', 'yan3')},
#  {('昂藏', 'ang2', 'zang2')},
#  {('囂藹', 'ao2', 'ai3')},
#  {('翱翔', 'ao2', 'xiang2')},
#  {('懊憦', 'ao4', 'lao4')},
#  {('懊惱', 'ao4', 'nao3')},
#  {('斑剝', 'ban1', 'bo1')},
#  {('苯䔿', 'ben3', 'zun3')},
#  {('崩騰', 'beng1', 'teng2')},
#  {('菶茸', 'beng3', 'rong2')},
#  {('逼迸', 'bi1', 'beng4')},
#  {('觱發', 'bi4', 'bo1'), ('觱發', 'bi4', 'fa1')},
#  {('觱沸', 'bi4', 'fei4')},
#  {('蔽芾', 'bi4', 'fei4')},
#  {('襞襀', 'bi4', 'ji1')},
#  {('赑屓', 'bi4', 'xi4')},
#  {('辟易', 'bi4', 'yi4'), ('避易', 'bi4', 'yi4')},
#  {('髟鼬', 'biao1', 'you4')},
#  {('蹩躠', 'bie2', 'xie4')},
#  {('玢豳', 'bin1', 'bin1')},
#  {('繽紛', 'bin1', 'fen1')},
#  {('驞駍', 'bin1', 'peng1')},
#  {('屏營', 'bing2', 'ying2')},
#  {('撥剌', 'bo1', 'la4')},
#  {('勃窣', 'bo2', 'su1')},
#  {('布濩', 'bu4', 'hu4')},
#  {('驂驔', 'can1', 'dian4')},
#  {('參潭', 'can1', 'tan2'), ('參驔', 'can1', 'tan2')},
#  {('慘悴', 'can3', 'cui4')},
#  {('燦爛', 'can4', 'lan4')},
#  {('蒼黃', 'cang1', 'huang2')},
#  {('滄浪', 'cang1', 'lang2')},
#  {('蒼茫', 'cang1', 'mang2')},
#  {('蒼莽', 'cang1', 'mang3')},
#  {('傖獰', 'cang1', 'ning2')},
#  {('摧藏', 'cang2', 'cui1'), ('藏催', 'cang2', 'cui1')},
#  {('嘈啐', 'cao2', 'cui4')},
#  {('嘈雜', 'cao2', 'za2')},
#  {('嘈囋', 'cao2', 'za2')},
#  {('草次', 'cao3', 'ci4')},
#  {('惻愴', 'ce4', 'chuang4')},
#  {('參差', 'cen1', 'ci1')},
#  {('岑崟', 'cen2', 'yin2')},
#  {('蹭蹬', 'ceng4', 'deng4')},
#  {('查牙', 'cha2', 'ya2')},
#  {('差池', 'cha4', 'chi2'), ('差池', 'ci1', 'chi2'), ('柴池', 'ci1', 'chi2')},
#  {('侘傺', 'cha4', 'chi4')},
#  {('瀺灂', 'chan2', 'chan2'), ('瀺灂', 'chan2', 'zhuo2')},
#  {('蟾蜍', 'chan2', 'chu2')},
#  {('纏綿', 'chan2', 'mian2')},
#  {('澶湉', 'chan2', 'tian2')},
#  {('嬋媛', 'chan2', 'yuan2'), ('蟬媛', 'chan2', 'yuan2')},
#  {('潺湲', 'chan2', 'yuan2')},
#  {('猖狂', 'chang1', 'kuang2')},
#  {('敞怳', 'chang3', 'huang3')},
#  {('惝怳', 'chang3', 'huang3'), ('惝恍', 'chang3', 'huang3')},
#  {('悵望', 'chang4', 'wang4')},
#  {('怊悵', 'chao1', 'chang4')},
#  {('呫囓', 'che4', 'nie4')},
#  {('趻踔', 'chen3', 'chuo1'), ('踸踔', 'chen3', 'chuo1')},
#  {('噌吰', 'cheng1', 'hong2')},
#  {('搶攘', 'cheng2', 'rang3')},
#  {('彳亍', 'chi4', 'chu4')},
#  {('佁儗', 'chi4', 'yi4')},
#  {('充斥', 'chong1', 'chi4')},
#  {('憧憬', 'chong1', 'jing3')},
#  {('舂容', 'chong1', 'rong2')},
#  {('衝蓯', 'chong3', 'zong3')},
#  {('惆悵', 'chou2', 'chang4')},
#  {('躊躇', 'chou2', 'chu2')},
#  {('愁疾', 'chou2', 'ji2')},
#  {('綢繆', 'chou2', 'mou2')},
#  {('儲與', 'chu2', 'yu3')},
#  {('惴耎', 'chuan3', 'ruan3')},
#  {('愴怳', 'chuang3', 'huang3')},
#  {('炊累', 'chui4', 'lei4')},
#  {('逴躒', 'chuo1', 'luo4')},
#  {('綽約', 'chuo4', 'yue1')},
#  {('汋約', 'chuo4', 'yue1')},
#  {('淖約', 'chuo4', 'yue1')},
#  {('茈虒', 'ci3', 'zhi4')},
#  {('蔥蘢', 'cong1', 'long3')},
#  {('從容', 'cong1', 'rong2')},
#  {('叢殘', 'cong2', 'can2')},
#  {('踧踖', 'cu4', 'ji2')},
#  {('巑岏', 'cuan2', 'wan2')},
#  {('攢雜', 'cuan2', 'za2')},
#  {('漼溰', 'cui1', 'yi2')},
#  {('璀璨', 'cui3', 'can4')},
#  {('璀錯', 'cui3', 'cuo4')},
#  {('翠微', 'cui4', 'wei1')},
#  {('蹉跌', 'cuo1', 'die1')},
#  {('蹉跎', 'cuo1', 'tuo2')},
#  {('嵯峨', 'cuo2', 'e2'), ('嵳峩', 'cuo2', 'e2')},
#  {('駘蕩', 'dai4', 'dang4')},
#  {('澶漫', 'dan2', 'man4')},
#  {('澹泊', 'dan4', 'bo2')},
#  {('澹淡', 'dan4', 'dan4')},
#  {('澹蕩', 'dan4', 'dang4')},
#  {('淡沱', 'dan4', 'duo4')},
#  {('澹灧', 'dan4', 'yan4')},
#  {('宕冥', 'dang4', 'ming2')},
#  {('唐突', 'dang4', 'tu2'), ('碭突', 'dang4', 'tu2')},
#  {('忉怛', 'dao1', 'da2')},
#  {('燾傲', 'dao4', 'ao4'), ('燾奡', 'dao4', 'ao4')},
#  {('滴瀝', 'di1', 'li4')},
#  {('玓瓑', 'di4', 'li4')},
#  {('的皪', 'di4', 'li4')},
#  {('稠嶅', 'diao4', 'ao2'), ('稠磝', 'diao4', 'ao2')},
#  {('嵽嵲', 'die2', 'nie4')},
#  {('蹀躞', 'die2', 'xie4'), ('躞蹀', 'die2', 'xie4')},
#  {('濎濘', 'ding3', 'ning2')},
#  {('飣餖', 'ding4', 'dou4')},
#  {('汀濘', 'ding4', 'ning2')},
#  {('抖擻', 'dou3', 'sou3')},
#  {('憞溷', 'dun1', 'hun2')},
#  {('袢廷', 'fan2', 'yan2')},
#  {('氾瀾', 'fan4', 'lan2'),
#   ('汎瀾', 'fan4', 'lan2'),
#   ('泛瀾', 'fan4', 'lan2'),
#   ('范瀾', 'fan4', 'lan2')},
#  {('芳菲', 'fang1', 'fei1')},
#  {('沸濆', 'fei1', 'pen1')},
#  {('菲薇', 'fei3', 'wei1')},
#  {('怫愄', 'fei4', 'wei4')},
#  {('沸渭', 'fei4', 'wei4')},
#  {('紛綸', 'fen1', 'lun2')},
#  {('氛氳', 'fen1', 'yun1'), ('雰氳', 'fen1', 'yun1')},
#  {('芬氳', 'fen1', 'yun1')},
#  {('紛紜', 'fen1', 'yun2')},
#  {('蚡緼', 'fen2', 'yun1')},
#  {('豐茸', 'feng1', 'rong2')},
#  {('扶疏', 'fu2', 'shu1')},
#  {('扶搖', 'fu2', 'yao2')},
#  {('怫鬱', 'fu2', 'yu4')},
#  {('愅詭', 'ge2', 'gui3')},
#  {('梗概', 'geng3', 'gai4')},
#  {('鉤輖', 'gou1', 'zhou1')},
#  {('汩稽', 'gu3', 'ji1'), ('滑稽', 'gu3', 'ji1')},
#  {('姽嫿', 'gui3', 'hua4')},
#  {('詭譎', 'gui3', 'jue2')},
#  {('詭隨', 'gui3', 'sui2')},
#  {('咍台', 'hai2', 'tai2')},
#  {('谽谺', 'han1', 'xia1')},
#  {('顄淡', 'han4', 'dan4')},
#  {('汗漫', 'han4', 'man4')},
#  {('杭壯', 'hang2', 'zhuang1')},
#  {('沆漭', 'hang4', 'mang3')},
#  {('沆瀣', 'hang4', 'xie4')},
#  {('號咷', 'hao2', 'tao2')},
#  {('浩溔', 'hao4', 'yao3'), ('灝溔', 'hao4', 'yao3'), ('皓溔', 'hao4', 'yao3')},
#  {('輷輘', 'hong1', 'leng2')},
#  {('硡隱', 'hong1', 'yin3')},
#  {('鴻洞', 'hong2', 'dong4')},
#  {('泓宏', 'hong2', 'hong2')},
#  {('泓汯', 'hong2', 'hong2')},
#  {('鴻蒙', 'hong2', 'meng2')},
#  {('港洞', 'hong4', 'dong4')},
#  {('淴泱', 'hu1', 'yang3')},
#  {('萑蔰', 'huan2', 'hu4')},
#  {('萑蘭', 'huan2', 'lan2')},
#  {('奐衍', 'huan4', 'yan3')},
#  {('荒唐', 'huang1', 'tang2')},
#  {('熀爛', 'huang3', 'lan4')},
#  {('晃朗', 'huang3', 'lang3')},
#  {('洸洋', 'huang4', 'yang2')},
#  {('滉漾', 'huang4', 'yang4')},
#  {('揮霍', 'hui1', 'huo4')},
#  {('虺隤', 'hui1', 'tui2')},
#  {('薈蔚', 'hui4', 'wei4')},
#  {('混沌', 'hun4', 'dun4'), ('渾沌', 'hun4', 'dun4')},
#  {('豁落', 'huo4', 'luo4')},
#  {('濩落', 'huo4', 'luo4')},
#  {('瓠落', 'huo4', 'luo4')},
#  {('霍繹', 'huo4', 'yi4')},
#  {('佶屈', 'ji2', 'qu1')},
#  {('浹洽', 'jia1', 'qia4')},
#  {('檟楚', 'jia3', 'chu3')},
#  {('間關', 'jian1', 'guan1')},
#  {('洚洞', 'jiang4', 'dong4')},
#  {('嬌嬈', 'jiao1', 'rao2')},
#  {('嶕嶢', 'jiao1', 'yao2'),
#   ('嶕嶢', 'yao2', 'e4'),
#   ('嶢嶭', 'jiao1', 'yao2'),
#   ('嶢嶭', 'yao2', 'e4')},
#  {('叫條', 'jiao4', 'tiao2'), ('窌條', 'jiao4', 'tiao2')},
#  {('噭咷', 'jiao4', 'tiao4')},
#  {('碣磍', 'jie2', 'jia2')},
#  {('拮据', 'jie2', 'ju4')},
#  {('捷獵', 'jie2', 'lie4')},
#  {('巀櫱', 'jie2', 'nie4')},
#  {('詰誳', 'jie2', 'qu1')},
#  {('緊絭', 'jin3', 'quan4')},
#  {('齽齘', 'jin4', 'xie4')},
#  {('噤吟', 'jin4', 'yin2')},
#  {('徑廷', 'jing4', 'ting2')},
#  {('啾嘈', 'jiu1', 'cao2')},
#  {('轇轕', 'jiu1', 'ge1')},
#  {('啾唧', 'jiu1', 'ji1')},
#  {('鞠躬', 'ju1', 'gong1')},
#  {('侷促', 'ju2', 'cu4'), ('局促', 'ju2', 'cu4'), ('跼蹙', 'ju2', 'cu4')},
#  {('跼躅', 'ju2', 'zhu2')},
#  {('咀嚼', 'ju3', 'ju2')},
#  {('踽僂', 'ju3', 'lü3')},
#  {('痀僂', 'ju3', 'lü3')},
#  {('悁急', 'juan4', 'ji2')},
#  {('屈強', 'jue2', 'qiang2')},
#  {('屈橋', 'jue2', 'qiao2')},
#  {('矍鑠', 'jue2', 'shuo4')},
#  {('愷悌', 'kai3', 'ti4')},
#  {('嵁巖', 'kan1', 'yan2')},
#  {('顑頷', 'kan3', 'han4')},
#  {('阬衡', 'kang1', 'heng2')},
#  {('忼慨', 'kang1', 'kai3'), ('慷慨', 'kang1', 'kai3')},
#  {('骯髒', 'kang3', 'zang3')},
#  {('抗髒', 'kang4', 'zang3')},
#  {('㕉匝', 'ke1', 'za1')},
#  {('嶱嵑', 'ke3', 'ke3')},
#  {('鏗鍧', 'keng1', 'hong1')},
#  {('鏗鏘', 'keng1', 'qiang1')},
#  {('悾款', 'kong1', 'kuan3')},
#  {('倥侗', 'kong1', 'tong2')},
#  {('崆峒', 'kong1', 'tong2'),
#   ('空同', 'kong1', 'tong2'),
#   ('空洞', 'kong1', 'tong2')},
#  {('崆㟅', 'kong1', 'yang2')},
#  {('倥偬', 'kong3', 'zong3'), ('倥傯', 'kong3', 'zong3')},
#  {('怐愗', 'kou4', 'mao4')},
#  {('溝瞀', 'kou4', 'mao4')},
#  {('區霿', 'kou4', 'mao4')},
#  {('劻勷', 'kuang1', 'rang2')},
#  {('俇攘', 'kuang2', 'rang2')},
#  {('曠蕩', 'kuang4', 'dang4')},
#  {('爌熀', 'kuang4', 'huang3')},
#  {('壙埌', 'kuang4', 'lang2')},
#  {('懭悢', 'kuang4', 'lang3')},
#  {('睽睢', 'kui2', 'hui1')},
#  {('騤瞿', 'kui2', 'ju4')},
#  {('躨跜', 'kui2', 'ni2')},
#  {('磈磊', 'kui3', 'lei3')},
#  {('悃款', 'kun3', 'kuan3')},
#  {('菈擸', 'la1', 'la4')},
#  {('蘭單', 'lan2', 'dan1'), ('闌單', 'lan2', 'dan1')},
#  {('欄杆', 'lan2', 'gan1'), ('闌干', 'lan2', 'gan1')},
#  {('爛漫', 'lan4', 'man4')},
#  {('爁焱', 'lan4', 'yan4')},
#  {('啷噹', 'lang2', 'dang1'), ('琅當', 'lang2', 'dang1')},
#  {('浶浪', 'lao2', 'lang4')},
#  {('牢落', 'lao2', 'luo4')},
#  {('壘塊', 'lei3', 'kuai4'), ('磊塊', 'lei3', 'kuai4')},
#  {('磊砢', 'lei3', 'luo3')},
#  {('磊落', 'lei3', 'luo4')},
#  {('楞層', 'leng2', 'ceng2')},
#  {('輘轢', 'leng2', 'li4')},
#  {('離麋', 'li2', 'mi2')},
#  {('離靡', 'li2', 'mi3')},
#  {('離披', 'li2', 'pi1')},
#  {('栗烈', 'li4', 'lie4')},
#  {('漣洏', 'lian2', 'er2')},
#  {('聯娟', 'lian2', 'juan1')},
#  {('謰謱', 'lian2', 'lou2')},
#  {('聯卷', 'lian2', 'quan2')},
#  {('連卷', 'lian2', 'quan2')},
#  {('連軒', 'lian2', 'xuan1')},
#  {('漣漪', 'lian2', 'yi1')},
#  {('戀眷', 'lian4', 'juan4'), ('眷戀', 'lian4', 'juan4')},
#  {('瀲灧', 'lian4', 'yan4')},
#  {('梁昌', 'liang2', 'chang1')},
#  {('寥廓', 'liao2', 'kuo4')},
#  {('聊浪', 'liao2', 'lang2')},
#  {('飉濿', 'liao2', 'li4')},
#  {('嘹唳', 'liao2', 'li4')},
#  {('飂戾', 'liao2', 'li4')},
#  {('漻浰', 'liao2', 'li4')},
#  {('寥唳', 'liao2', 'li4'), ('寥戾', 'liao2', 'li4')},
#  {('寥亮', 'liao2', 'liang4')},
#  {('嘹亮', 'liao2', 'liang4')},
#  {('寥落', 'liao2', 'luo4')},
#  {('繚繞', 'liao2', 'rao4')},
#  {('潦倒', 'liao3', 'dao3')},
#  {('憭慄', 'liao3', 'li4')},
#  {('列缺', 'lie4', 'que1'), ('裂缺', 'lie4', 'que1')},
#  {('璘班', 'lin2', 'ban1')},
#  {('璘彬', 'lin2', 'bin1'), ('瞵彬', 'lin2', 'bin1')},
#  {('琳瑯', 'lin2', 'lang2')},
#  {('淋灕', 'lin2', 'li2')},
#  {('惏悷', 'lin2', 'li4')},
#  {('轔轢', 'lin2', 'li4'), ('轔轢', 'lin4', 'li4')},
#  {('燐亂', 'lin2', 'luan4')},
#  {('嶙峋', 'lin2', 'xun2')},
#  {('蹸轢', 'lin4', 'li4'), ('躪轢', 'lin4', 'li4'), ('轥轢', 'lin4', 'li4')},
#  {('零丁', 'ling2', 'ding1')},
#  {('輘輷', 'ling2', 'hong1')},
#  {('岺巆', 'ling2', 'hong1')},
#  {('凌歷', 'ling2', 'li4')},
#  {('凌厲', 'ling2', 'li4')},
#  {('岺嶙', 'ling2', 'lin2')},
#  {('碐磳', 'ling2', 'zeng1')},
#  {('懰慄', 'liu2', 'li4')},
#  {('流連', 'liu2', 'lian2')},
#  {('瀏亮', 'liu2', 'liang4')},
#  {('留落', 'liu2', 'luo4')},
#  {('䚧觩', 'liu2', 'qiu2')},
#  {('蟉虯', 'liu2', 'qiu2')},
#  {('穹隆', 'long2', 'qiong2'), ('隆穹', 'long2', 'qiong2')},
#  {('巃嵸', 'long2', 'song3')},
#  {('龍鐘', 'long2', 'zhong1')},
#  {('蔥蘢', 'long3', 'cong1'), ('蘢蔥', 'long3', 'cong1')},
#  {('趢趗', 'lu4', 'cu4')},
#  {('陸離', 'lu4', 'li2')},
#  {('陸梁', 'lu4', 'liang2')},
#  {('碌硞', 'lu4', 'que4')},
#  {('淪落', 'lun2', 'luo4')},
#  {('覶縷', 'luo2', 'lü2')},
#  {('駱漠', 'luo4', 'mo4')},
#  {('樂託', 'luo4', 'tuo1')},
#  {('絡繹', 'luo4', 'yi4')},
#  {('麻茶', 'ma2', 'cha2')},
#  {('霡霂', 'mai4', 'mu4')},
#  {('霢霂', 'mai4', 'mu4')},
#  {('漫漶', 'man4', 'huan4')},
#  {('曼羨', 'man4', 'xian4')},
#  {('曼衍', 'man4', 'yuan3')},
#  {('茫昧', 'mang2', 'mei4')},
#  {('茫洋', 'mang2', 'yang2')},
#  {('莽蒼', 'mang3', 'cang3')},
#  {('漭漾', 'mang3', 'yang4'), ('莽漾', 'mang3', 'yang4')},
#  {('酕醄', 'mao2', 'tao2')},
#  {('毷氉', 'mao4', 'sao4')},
#  {('昧莫', 'mei4', 'mo4')},
#  {('尨茸', 'meng2', 'rong2')},
#  {('瞢騰', 'meng2', 'teng2')},
#  {('孟浪', 'meng4', 'lang2')},
#  {('彌漫', 'mi2', 'man4')},
#  {('瀰漫', 'mi2', 'man4')},
#  {('迷密', 'mi2', 'mi4')},
#  {('孊密', 'mi3', 'mi4')},
#  {('幎歷', 'mi4', 'li4')},
#  {('密勿', 'mi4', 'wu4')},
#  {('矊眇', 'mian2', 'miao3')},
#  {('瞑眩', 'mian4', 'xian4')},
#  {('蔑蒙', 'mie4', 'meng2')},
#  {('黽勉', 'min3', 'mian3')},
#  {('溟漭', 'ming2', 'mang3')},
#  {('茗邈', 'ming2', 'miao3')},
#  {('溟沐', 'ming2', 'mu4')},
#  {('摩何', 'mo2', 'he2')},
#  {('模糊', 'mo2', 'hu2')},
#  {('撓挑', 'nao2', 'tiao1')},
#  {('膩細', 'ni4', 'xi4')},
#  {('裊娜', 'niao3', 'nuo2')},
#  {('囁嚅', 'nie4', 'ru2')},
#  {('杌隉', 'nie4', 'wu4'), ('蘖卼', 'nie4', 'wu4'), ('阢隉', 'nie4', 'wu4')},
#  {('濘溺', 'ning2', 'ni4')},
#  {('忸怩', 'niu3', 'ni2')},
#  {('嘔啞', 'ou1', 'ya3')},
#  {('嘔軋', 'ou1', 'ya4')},
#  {('爬沙', 'pa2', 'sha1')},
#  {('槃礡', 'pan2', 'bo2')},
#  {('盤桓', 'pan2', 'huan2')},
#  {('泮汗', 'pan4', 'han4')},
#  {('判換', 'pan4', 'huan4')},
#  {('滂濞', 'pang1', 'pi4')},
#  {('磅唐', 'pang2', 'bo2'), ('磅礴', 'pang2', 'bo2')},
#  {('旁魄', 'pang2', 'bo2')},
#  {('滂沛', 'pang2', 'pei4')},
#  {('滂沱', 'pang2', 'tuo2')},
#  {('泡溲', 'pao2', 'sou3')},
#  {('噴薄', 'pen1', 'bo2')},
#  {('噴薄', 'pen1', 'bo2'), ('濆礴', 'pen1', 'bo2'), ('濆薄', 'pen1', 'bo2')},
#  {('輣訇', 'peng1', 'hong1')},
#  {('硼磕', 'peng1', 'ke1'), ('硼磕', 'peng2', 'ke1')},
#  {('淜湃', 'peng1', 'pai4')},
#  {('澎濞', 'peng1', 'pi4')},
#  {('硼隱', 'peng1', 'yin3')},
#  {('膨脝', 'peng2', 'heng1')},
#  {('髬髵', 'pi1', 'er2')},
#  {('霹靂', 'pi1', 'li4')},
#  {('披靡', 'pi1', 'mi3')},
#  {('俾倪', 'pi3', 'ni2'), ('埤坭', 'pi3', 'ni2')},
#  {('俾倪', 'pi4', 'ni4'), ('埤坭', 'pi4', 'ni4')},
#  {('埤堄', 'pi4', 'ni4'), ('睥睨', 'pi4', 'ni4')},
#  {('翩飄', 'pian1', 'piao1')},
#  {('便辟', 'pian2', 'pi4')},
#  {('輣闐', 'pian2', 'tian2')},
#  {('蹁躚', 'pian2', 'xian1')},
#  {('飄搖', 'piao1', 'yao2')},
#  {('嫖姚', 'piao1', 'yao2'), ('飄搖', 'piao1', 'yao2')},
#  {('瞟眇', 'piao3', 'miao3'), ('縹緲', 'piao3', 'miao3')},
#  {('僄狡', 'piao4', 'jiao3')},
#  {('瞥列', 'pie1', 'lie4')},
#  {('瞥裂', 'pie1', 'lie4')},
#  {('潎洌', 'pie4', 'lie4')},
#  {('頻煩', 'pin2', 'fan2')},
#  {('嚬呻', 'pin2', 'shen1')},
#  {('娉婷', 'ping1', 'ting2')},
#  {('淜滂', 'ping2', 'pang1')},
#  {('苹縈', 'ping2', 'ying2')},
#  {('坡坨', 'po1', 'tuo2')},
#  {('陂阤', 'po1', 'tuo2'), ('陂陀', 'po1', 'tuo2')},
#  {('駊騀', 'po3', 'e2')},
#  {('溥漠', 'po4', 'mo4')},
#  {('匍匐', 'pu2', 'fu2'), ('葡伏', 'pu2', 'fu2'), ('葡服', 'pu2', 'fu2')},
#  {('朴簌', 'pu3', 'su4')},
#  {('棲遲', 'qi1', 'chi2')},
#  {('淒楚', 'qi1', 'chu3')},
#  {('萋斐', 'qi1', 'fei3')},
#  {('㩻䧢', 'qi1', 'qu1')},
#  {('攲缺', 'qi1', 'que1')},
#  {('崎嶇', 'qi2', 'qu1')},
#  {('岐嶷', 'qi2', 'yi2'), ('崎嶷', 'qi2', 'yi2')},
#  {('碕礒', 'qi2', 'yi3')},
#  {('契闊', 'qi4', 'kuo4')},
#  {('磧歷', 'qi4', 'li4'), ('磧礫', 'qi4', 'li4')},
#  {('嵌巖', 'qian1', 'yan2')},
#  {('繾綣', 'qian3', 'quan3')},
#  {('鎗玲', 'qiang1', 'ling2')},
#  {('瑲玲', 'qiang1', 'ling2')},
#  {('槍欀', 'qiang1', 'xiang1')},
#  {('愀愴', 'qiao3', 'chuang4')},
#  {('巧老', 'qiao3', 'lao3')},
#  {('踥跌', 'qie4', 'die2')},
#  {('嶔岑', 'qin1', 'cen2')},
#  {('嶔崎', 'qin1', 'qi2')},
#  {('侵尋', 'qin1', 'xun2')},
#  {('浸潯', 'qin1', 'yin2')},
#  {('浸淫', 'qin1', 'yin2')},
#  {('青熒', 'qing1', 'ying2')},
#  {('丘虛', 'qiu1', 'xu1')},
#  {('蜷局', 'quan2', 'ju2'), ('蜷跼', 'quan2', 'ju2')},
#  {('礐硞', 'que4', 'ke4')},
#  {('逡巡', 'qun1', 'xun2')},
#  {('逡循', 'qun1', 'xun2')},
#  {('姌嫋', 'ran3', 'niao3')},
#  {('苒弱', 'ran3', 'ruo4')},
#  {('擾攘', 'rao3', 'rang3')},
#  {('擾弱', 'rao3', 'ru4')},
#  {('溶㵝', 'rong2', 'yi4')},
#  {('容與', 'rong2', 'yu3'), ('溶與', 'rong2', 'yu3')},
#  {('嚅唲', 'ru2', 'er2')},
#  {('颯爽', 'sa4', 'shuang3')},
#  {('颯沓', 'sa4', 'ta4')},
#  {('騷搔', 'sao1', 'sao1')},
#  {('騷屑', 'sao1', 'xie4')},
#  {('呻吟', 'shen1', 'yin2')},
#  {('率爾', 'shuai4', 'er3')},
#  {('斯須', 'si1', 'xu1')},
#  {('搜牢', 'sou1', 'lao4')},
#  {('颼飀', 'sou1', 'liu2')},
#  {('索落', 'suo3', 'luo4')},
#  {('荅焉', 'ta1', 'yan1')},
#  {('沓合', 'ta4', 'he2')},
#  {('㯓臘', 'ta4', 'la4')},
#  {('嗒焉', 'ta4', 'yan1')},
#  {('曇欒', 'tan2', 'luan2')},
#  {('憛悇', 'tan2', 'tu2')},
#  {('戃慌', 'tang3', 'huang1')},
#  {('曭朗', 'tang3', 'lang3')},
#  {('曭莽', 'tang3', 'mang3')},
#  {('挑達', 'tao1', 'da2')},
#  {('叨沓', 'tao1', 'ta4')},
#  {('俶儻', 'ti4', 'tang3')},
#  {('倜儻', 'ti4', 'tang3')},
#  {('惕息', 'ti4', 'xi1')},
#  {('淟涊', 'tian3', 'nian3')},
#  {('迢遞', 'tiao2', 'di4')},
#  {('岧嵽', 'tiao2', 'di4'),
#   ('岧嵽', 'tiao2', 'yao2'),
#   ('岧嶤', 'tiao2', 'di4'),
#   ('岧嶤', 'tiao2', 'yao2'),
#   ('岹嵽', 'tiao2', 'di4'),
#   ('岹嵽', 'tiao2', 'yao2'),
#   ('岹嶤', 'tiao2', 'di4'),
#   ('岹嶤', 'tiao2', 'yao2')},
#  {('誂越', 'tiao3', 'yue4')},
#  {('餮切', 'tie4', 'qie4')},
#  {('渟瀯', 'ting2', 'ying2')},
#  {('渟濙', 'ting2', 'ying3')},
#  {('濎濙', 'ting4', 'ying2')},
#  {('汀濴', 'ting4', 'ying4')},
#  {('瞳矇', 'tong2', 'meng2')},
#  {('氃氋', 'tong2', 'meng2')},
#  {('突兀', 'tu1', 'wu4')},
#  {('秃兀', 'tu1', 'wu4')},
#  {('悇憛', 'tu2', 'tan2')},
#  {('妥帖', 'tuo3', 'tie1')},
#  {('唲嘔', 'wa1', 'ou1')},
#  {('頑鈍', 'wan1', 'dun4')},
#  {('蜿蜒', 'wan1', 'yan2')},
#  {('婉戀', 'wan3', 'lian4')},
#  {('涴演', 'wan3', 'yan3')},
#  {('婉轉', 'wan3', 'zhuan3')},
#  {('望洋', 'wang1', 'xiang2'),
#   ('汪洋', 'wang1', 'xiang2'),
#   ('汪漾', 'wang1', 'xiang2'),
#   ('汪翔', 'wang1', 'xiang2')},
#  {('瀇漾', 'wang3', 'yang4'), ('瀇瀁', 'wang3', 'yang4')},
#  {('旺相', 'wang4', 'xiang1')},
#  {('倭遲', 'wei1', 'chi2')},
#  {('崴嵬', 'wei1', 'wei2')},
#  {('逶迤', 'wei1', 'yi2')},
#  {('萎約', 'wei1', 'yue1')},
#  {('巍峨', 'wei2', 'e2'), ('巍峩', 'wei2', 'e2')},
#  {('萎腇', 'wei3', 'nei3')},
#  {('委蛇', 'wei3', 'she2'), ('委蛇', 'wei3', 'yi2')},
#  {('磈硊', 'wei3', 'wei3')},
#  {('蓊茸', 'weng3', 'rong2')},
#  {('蓊鬱', 'weng3', 'yu4')},
#  {('婐㛂', 'wo3', 'nuo3')},
#  {('偓促', 'wo4', 'cu4')},
#  {('嗚乎', 'wu1', 'hu1'),
#   ('嗚呼', 'wu1', 'hu1'),
#   ('嗚虖', 'wu1', 'hu1'),
#   ('烏乎', 'wu1', 'hu1'),
#   ('烏呼', 'wu1', 'hu1'),
#   ('烏虖', 'wu1', 'hu1')},
#  {('嗚咽', 'wu1', 'ye1'), ('嗚咽', 'wu1', 'ye4')},
#  {('嫵媚', 'wu3', 'mei4')},
#  {('沕潏', 'wu4', 'jue2')},
#  {('沕穆', 'wu4', 'mu4')},
#  {('溪刻', 'xi1', 'ke4')},
#  {('淅瀝', 'xi1', 'li4')},
#  {('翕赩', 'xi1', 'xi4')},
#  {('肸蠁', 'xi1', 'xiang4')},
#  {('棲屑', 'xi1', 'xie4')},
#  {('希夷', 'xi1', 'yi2')},
#  {('謑髁', 'xi2', 'ke1')},
#  {('襲雜', 'xi2', 'za2')},
#  {('徙倚', 'xi3', 'yi3')},
#  {('屓奰', 'xi4', 'bi4'), ('屭奰', 'xi4', 'bi4')},
#  {('翕赫', 'xi4', 'he4')},
#  {('浹渫', 'xia2', 'die2')},
#  {('睍睆', 'xian4', 'huan3'), ('睍睆', 'xian4', 'huan4')},
#  {('象罔', 'xiang4', 'wang3')},
#  {('澩㺒', 'xiao1', 'qiao1')},
#  {('瀟灑', 'xiao1', 'sa3'), ('蕭灑', 'xiao1', 'sa3')},
#  {('瀟瑟', 'xiao1', 'se4'), ('蕭瑟', 'xiao1', 'se4')},
#  {('瀟森', 'xiao1', 'sen1'), ('蕭森', 'xiao1', 'sen1')},
#  {('蕭蔘', 'xiao1', 'shen1')},
#  {('瀟率', 'xiao1', 'shuai4'), ('蕭率', 'xiao1', 'shuai4')},
#  {('蕭肅', 'xiao1', 'su4')},
#  {('瀟索', 'xiao1', 'suo3'), ('蕭索', 'xiao1', 'suo3')},
#  {('瀟條', 'xiao1', 'tiao2'), ('蕭條', 'xiao1', 'tiao2')},
#  {('瀟條', 'xiao1', 'tiao2'), ('蕭條', 'xiao1', 'tiao2')},
#  {('蕭閒', 'xiao1', 'xian2')},
#  {('庨窌', 'xiao2', 'liao2')},
#  {('皛溔', 'xiao3', 'yao3')},
#  {('澩灂', 'xiao4', 'zhuo2')},
#  {('頡頏', 'xie2', 'hang2')},
#  {('頡滑', 'xie2', 'hua2')},
#  {('洶湧', 'xiong1', 'yong3')},
#  {('歔欷', 'xu1', 'xi1')},
#  {('歘吸', 'xu1', 'xi1')},
#  {('戌削', 'xu1', 'xue1')},
#  {('須臾', 'xu1', 'yu2')},
#  {('姁媮', 'xu3', 'yu2')},
#  {('蓄縮', 'xu4', 'suo1')},
#  {('漩澴', 'xuan2', 'huan2')},
#  {('烜爀', 'xuan3', 'he4')},
#  {('眴煥', 'xuan4', 'huan4')},
#  {('眩湣', 'xuan4', 'mian4')},
#  {('泫沄', 'xuan4', 'yun2')},
#  {('菴藹', 'yan3', 'ai3')},
#  {('偃蹇', 'yan3', 'jian3')},
#  {('黶翳', 'yan3', 'yi4')},
#  {('噞喁', 'yan3', 'yong2')},
#  {('焱悠', 'yan4', 'you1')},
#  {('鞅常', 'yang1', 'chang2')},
#  {('鞅掌', 'yang1', 'zhang3')},
#  {('泱漭', 'yang3', 'mang3')},
#  {('泱灢', 'yang3', 'nang3')},
#  {('怏悒', 'yang4', 'yi4')},
#  {('窐寥', 'yao1', 'liao2')},
#  {('么麼', 'yao1', 'mo2')},
#  {('夭矯', 'yao1', 'qiao3')},
#  {('妖嬈', 'yao1', 'rao3')},
#  {('妖冶', 'yao1', 'ye3')},
#  {('搖曳', 'yao2', 'ye4')},
#  {('杳眇', 'yao3', 'miao3'), ('窅眇', 'yao3', 'miao3')},
#  {('揶揄', 'ye2', 'yu2')},
#  {('嶪峨', 'ye4', 'e2'), ('嶪峩', 'ye4', 'e2'), ('嶫峨', 'ye4', 'e2')},
#  {('曵曳', 'ye4', 'ye4')},
#  {('依稀', 'yi1', 'xi1')},
#  {('伊邑', 'yi1', 'yi4')},
#  {('猗歟', 'yi1', 'yu3')},
#  {('伊鬱', 'yi1', 'yu4')},
#  {('依約', 'yi1', 'yue1')},
#  {('夷靡', 'yi2', 'mi2')},
#  {('陁靡', 'yi2', 'mi3')},
#  {('夷猶', 'yi2', 'you2')},
#  {('迤靡', 'yi3', 'mi3')},
#  {('旖旎', 'yi3', 'ni3')},
#  {('靉霼', 'yi3', 'xi4')},
#  {('蘙蔚', 'yi4', 'hui4'),
#   ('蘙蔚', 'yi4', 'wei4'),
#   ('蘙薈', 'yi4', 'hui4'),
#   ('蘙薈', 'yi4', 'wei4')},
#  {('熠燿', 'yi4', 'yao4')},
#  {('佚豫', 'yi4', 'yu4')},
#  {('抑鬱', 'yi4', 'yu4')},
#  {('屹崒', 'yi4', 'zu2'), ('屹崪', 'yi4', 'zu2')},
#  {('愔翳', 'yin1', 'yi4')},
#  {('烟熅', 'yin1', 'yun1')},
#  {('夤緣', 'yin2', 'yuan2')},
#  {('嚶喔', 'ying1', 'o1'), ('嚶喔', 'ying1', 'wo1')},
#  {('熒惑', 'ying2', 'huo4')},
#  {('縈紆', 'ying2', 'yu1')},
#  {('巊冥', 'ying3', 'ming2')},
#  {('悠揚', 'you1', 'yang2')},
#  {('優柔', 'you1', 'you2'), ('優游', 'you1', 'you2'), ('優遊', 'you1', 'you2')},
#  {('猶豫', 'you2', 'yu4')},
#  {('黝糾', 'you3', 'jiu1')},
#  {('蚴虯', 'you3', 'qiu2')},
#  {('紆餘', 'yu1', 'yu2')},
#  {('揄揚', 'yu2', 'yang2')},
#  {('蔚結', 'yu4', 'jie2'),
#   ('蔚結', 'yu4', 'yi4'),
#   ('鬱悒', 'yu4', 'jie2'),
#   ('鬱悒', 'yu4', 'yi4')},
#  {('燠煜', 'yu4', 'yu4')},
#  {('雜錯', 'za2', 'cuo4')},
#  {('雜遝', 'za2', 'ta4')},
#  {('雜襲', 'za2', 'xi2')},
#  {('造次', 'zao4', 'ci4')},
#  {('砟硌', 'zha4', 'luo4')},
#  {('咤沙', 'zha4', 'sha1')},
#  {('占斷', 'zhan1', 'duan4')},
#  {('展轉', 'zhan3', 'zhuan3'), ('輾轉', 'zhan3', 'zhuan3')},
#  {('展轉', 'zhan3', 'zhuan3'), ('輾轉', 'zhan3', 'zhuan3')},
#  {('啁哳', 'zhao1', 'zha1')},
#  {('斟酌', 'zhen1', 'zhuo2')},
#  {('鬇鬡', 'zheng1', 'ning2')},
#  {('崢嶸', 'zheng1', 'rong2')},
#  {('征營', 'zheng1', 'ying2'),
#   ('正營', 'zheng1', 'ying2'),
#   ('正營', 'zheng4', 'ying2')},
#  {('鄭重', 'zheng4', 'zhong4')},
#  {('咫尺', 'zhi3', 'chi3')},
#  {('踶跂', 'zhi4', 'zhi1')},
#  {('忪懞', 'zhong1', 'meng2')},
#  {('輈張', 'zhou1', 'zhang1')},
#  {('卓犖', 'zhuo1', 'luo4')},
#  {('咨嗟', 'zi1', 'jie1')},
#  {('趑趄', 'zi1', 'ju1')},
#  {('嵫釐', 'zi1', 'li2')},
#  {('恣睢', 'zi4', 'sui1')},
#  {('齱齵', 'zou1', 'ou2')},
#  {('崒兀', 'zu2', 'wu4')},
#  {('蕞爾', 'zui4', 'er3')},
#  {('岝崿', 'zuo2', 'e4'), ('岞崿', 'zuo2', 'e4')}]

# %%
import pprint
with open('20220428-combined-binome-clusters.txt', 'w') as f:
    f.write(pprint.pformat(CLUSTERS_PARSED))

# %%
cluster_idx_to_prons_cleaned = defaultdict(list)
for idx, st in enumerate(CLUSTERS_PARSED):
    for (binome, first, second) in st:
        cluster_idx_to_prons_cleaned[idx].append((first, second))

for i in range(len(CLUSTERS_PARSED)):
    for (first, second) in cluster_idx_to_prons_cleaned[i]:
        if any(((first, second) in cluster_idx_to_prons_cleaned[j]) or ((second, first) in cluster_idx_to_prons_cleaned[j]) for j in range(i)):
            print(i, first, second)
# Out:
# 21 hun2 lun2
# 21 hun2 lun2
# 69 cui4 cai4
# 159 tong2 meng2
# 159 tong2 meng2
# 163 xi1 xie4
# 168 pang2 yang2
# 186 zhou1 jiu1
# 186 zhou1 jiao1
# 186 zhou1 jiao1
# 214 bi4 bo1
# 216 bi4 fei4
# 233 cang1 huang2
# 241 cao2 za2
# 255 chan2 yuan2
# 258 chang3 huang3
# 258 chang3 huang3
# 281 chuo4 yue1
# 282 chuo4 yue1
# 284 cong1 long3
# 310 di4 li4
# 313 die2 xie4
# 313 die2 xie4
# 325 fei4 wei4
# 328 fen1 yun1
# 330 fen2 yun1
# 334 fu2 yu4
# 344 han4 dan4
# 355 hong2 hong2
# 357 hong4 dong4
# 372 huo4 luo4
# 373 huo4 luo4
# 401 ju3 lü3
# 419 kong1 tong2
# 419 kong1 tong2
# 419 kong1 tong2
# 423 kou4 mao4
# 424 kou4 mao4
# 457 lian2 quan2
# 466 liao2 li4
# 467 liao2 li4
# 468 liao2 li4
# 469 liao2 li4
# 469 liao2 li4
# 471 liao2 liang4
# 480 lin2 li2
# 482 lin2 li4
# 485 lin4 li4
# 485 lin4 li4
# 485 lin4 li4
# 488 ling2 hong1
# 490 ling2 li4
# 498 liu2 qiu2
# 502 long3 cong1
# 502 long3 cong1
# 514 mai4 mu4
# 529 mi2 man4
# 537 min3 mian3
# 547 nie4 wu4
# 547 nie4 wu4
# 547 nie4 wu4
# 553 pan2 bo2
# 554 pan2 huan2
# 556 pan4 huan4
# 558 pang2 bo2
# 558 pang2 bo2
# 559 pang2 bo2
# 564 pen1 bo2
# 564 pen1 bo2
# 564 pen1 bo2
# 567 peng1 pai4
# 575 pi4 ni4
# 575 pi4 ni4
# 576 pi4 ni4
# 576 pi4 ni4
# 581 piao1 yao2
# 582 piao1 yao2
# 582 piao1 yao2
# 586 pie1 lie4
# 594 po1 tuo2
# 594 po1 tuo2
# 597 pu2 fu2
# 597 pu2 fu2
# 597 pu2 fu2
# 612 qiang1 ling2
# 621 qin1 yin2
# 627 qun1 xun2
# 652 tang3 lang3
# 657 ti4 tang3
# 661 tiao2 di4
# 661 tiao2 di4
# 661 tiao2 di4
# 661 tiao2 di4
# 668 tong2 meng2
# 669 tong2 meng2
# 671 tu1 wu4
# 672 tu2 tan2
# 681 wang3 yang4
# 681 wang3 yang4
# 704 xi1 xie4
# 709 xi4 bi4
# 709 xi4 bi4
# 723 xiao1 tiao2
# 723 xiao1 tiao2
# 732 xu1 xi1
# 771 yi3 ni3
# 776 yi4 yu4
# 779 yin1 yun1
# 786 you1 you2
# 786 you1 you2
# 786 you1 you2
# 792 yu4 yi4
# 792 yu4 yi4
# 796 za2 xi2
# 802 zhan3 zhuan3
# 802 zhan3 zhuan3
# 812 zhou1 zhang1

# %%
with open('20220428-combined-binome-clusters-cleaned.txt') as f:
    clusters_eval = eval(''.join(f.readlines()))
    
cluster_idx_to_binomes_cleaned = defaultdict(list)
for idx, st in enumerate(clusters_eval):
    for (binome, first, second) in st:
        cluster_idx_to_binomes_cleaned[idx].append(binome)

for i in range(len(cluster_idx_to_binomes_cleaned)):
    if any(b in cluster_idx_to_binomes_cleaned[j] for j in range(i) for b in cluster_idx_to_binomes_cleaned[i]):
        print(cluster_idx_to_binomes_cleaned[i])

# %%
import pprint
with open('20220428-combined-binome-clusters-FINAL.txt', 'w') as f:
    f.write(pprint.pformat(clusters_eval))

# %%
binomes_only = [{triplet[0] for triplet in st} for st in clusters_eval]
variants_only = [st for st in binomes_only if len(st) > 1]

# %%
for i, cluster in enumerate(variants_only):
    for binome in cluster:
        print(f'{i}\t{binome}')
# Out:
# 0	埤坭
# 0	睥睨
# 0	俾睨
# 0	俾倪
# 0	埤堄
# 1	篳篥
# 1	觱篥
# 2	倉庚
# 2	鶬鶊
# 3	嶄巗
# 3	巉巖
# 3	孱顏
# 3	嶄巖
# 4	硨磲
# 4	車渠
# 5	鉏鋙
# 5	岨峿
# 5	齟齬
# 6	躑躅
# 6	蹢躅
# 7	芍藥
# 7	勺藥
# 8	毒冒
# 8	瑇瑁
# 9	彷彿
# 9	仿佛
# 10	徬徨
# 10	仿偟
# 10	彷徨
# 10	房皇
# 10	傍偟
# 11	氤氳
# 11	茵蒀
# 11	葐蒀
# 11	絪縕
# 12	匍匐
# 12	蒲伏
# 12	葡伏
# 12	葡服
# 12	蒲服
# 12	扶伏
# 13	滈瀚
# 13	浩瀚
# 13	滈汗
# 13	浩汗
# 14	澒洞
# 14	虹洞
# 15	荒忽
# 15	芒忽
# 15	慌惚
# 15	惚恍
# 15	恍惚
# 15	怳惚
# 15	恍忽
# 15	惚怳
# 16	迦逅
# 16	邂逅
# 17	糾蓼
# 17	摎蓼
# 18	君遷
# 18	桾櫏
# 19	轗軻
# 19	坎軻
# 19	坎坷
# 20	崑崙
# 20	昆侖
# 20	渾淪
# 21	昆吾
# 21	琨珸
# 22	藍褸
# 22	襤縷
# 22	襤褸
# 22	藍縷
# 23	褵褷
# 23	褷褵
# 23	離褷
# 23	蘺褷
# 24	零落
# 24	苓落
# 25	瑪瑙
# 25	馬腦
# 26	僶俛
# 26	僶勉
# 26	閔勉
# 27	酩酊
# 27	茗艼
# 28	兠鍪
# 28	兠鞪
# 29	阢隉
# 29	蘖卼
# 29	杌隉
# 29	臲卼
# 30	媻娑
# 30	婆娑
# 31	咆哮
# 31	炰烋
# 32	裴徊
# 32	徘徊
# 33	魌丑
# 33	僛丑
# 34	蘧蒢
# 34	籧篨
# 35	劬錄
# 35	軥錄
# 36	鸜鵒
# 36	鴝鵒
# 37	茹蘆
# 37	蕠蘆
# 38	舑舕
# 38	舔舕
# 39	碭突
# 39	樘突
# 39	唐突
# 40	姚冶
# 40	窕冶
# 41	滂陁
# 41	滂陀
# 42	瀇漾
# 42	汪漾
# 42	汪翔
# 42	汪洋
# 42	瀇瀁
# 42	望洋
# 43	魍魎
# 43	罔閬
# 44	齷齱
# 44	齷齪
# 44	握齱
# 45	纖趨
# 45	孅趨
# 46	䆗窱
# 46	窈窕
# 47	殷勤
# 47	慇勤
# 47	慇懃
# 48	逍遙
# 48	招搖
# 49	侜張
# 49	譸張
# 50	侏儒
# 50	朱儒
# 51	倉猝
# 51	倉卒
# 52	蟕蠵
# 52	觜蠵
# 53	倉皇
# 53	倉煌
# 54	蠆芥
# 54	蠆介
# 55	蟬聯
# 55	蟬連
# 56	猖蹶
# 56	猖獗
# 57	蘢葱
# 57	葱蘢
# 58	綷粲
# 58	綷縩
# 59	跌蕩
# 59	跌宕
# 60	娥媓
# 60	娥皇
# 61	婀娜
# 61	娜婀
# 62	茀鬱
# 62	鬱岪
# 62	岪鬱
# 63	芙蓉
# 63	芙蕖
# 64	鈷䥈
# 64	鈷鉧
# 65	蒪苴
# 65	苴蒪
# 66	嬋娟
# 66	蟬娟
# 67	豆蔻
# 67	荳蔻
# 68	斕斒
# 68	斒斕
# 68	斕斑
# 69	儻閬
# 69	爣閬
# 69	爣朗
# 69	儻朗
# 70	荔枝
# 70	荔支
# 71	迤邐
# 71	邐迤
# 72	踉蹡
# 72	踉蹌
# 73	伶俜
# 73	俜伶
# 74	殑㱥
# 74	㱥殑
# 75	紗鰡
# 75	沙鰡
# 76	玲瓏
# 76	瓏玲
# 77	蘿勒
# 77	蘿艻
# 78	蝦蟆
# 78	蛤蟆
# 79	澒濛
# 79	濛澒
# 80	艨艟
# 80	艨衝
# 81	蠓蠛
# 81	蠛蠓
# 82	涬溟
# 82	溟涬
# 83	莫錯
# 83	錯莫
# 84	滂湃
# 84	澎湃
# 85	蹣連
# 85	媻姍
# 85	蹣辟
# 85	磐辟
# 85	蹣跚
# 85	媻珊
# 86	戚促
# 86	戚草
# 87	荏苒
# 87	苒荏
# 88	萎蕤
# 88	葳蕤
# 89	瑟索
# 89	瑟縮
# 90	僧祇
# 90	僧耆
# 91	倏忽
# 91	儵忽
# 92	壇曼
# 92	壇漫
# 93	町畽
# 93	町疃
# 94	膧朧
# 94	膧朦
# 94	曈曚
# 94	膧䑃
# 94	曈曨
# 95	汍蘭
# 95	汍瀾
# 96	險巇
# 96	巇險
# 97	恓屑
# 97	恓惶
# 98	惺鬆
# 98	惺忪
# 99	坱軋
# 99	坱圠
# 100	倘佯
# 100	徜徉
# 100	彷徉
# 101	枒杈
# 101	杈枒
# 102	猗儺
# 102	椅柅
# 102	猗狔
# 103	因巡
# 103	因循
# 104	優柔
# 104	優游
# 104	優遊
# 105	幼妙
# 105	幼眇
# 106	邅迍
# 106	迍邅
# 107	啁啾
# 107	啁噍
# 108	蓽茇
# 108	蓽撥
# 109	憔悴
# 109	蕉悴
# 109	憔萃
# 109	蕉萃
# 109	憔顇
# 110	磐礡
# 110	磐薄
# 110	盤薄
# 111	彯搖
# 111	票姚
# 112	葡桃
# 112	葡萄
# 113	阡眠
# 113	芊綿
# 113	芊眠
# 113	阡綿
# 114	鷫鷞
# 114	驌驦
# 115	相羊
# 115	忀徉
# 115	儴佯
# 116	黮䨴
# 116	黯黮
# 116	黮暗
# 117	辟易
# 117	避易
# 118	參驔
# 118	參潭
# 119	摧藏
# 119	藏催
# 120	柴池
# 120	差池
# 121	蟬媛
# 121	嬋媛
# 122	惝恍
# 122	惝怳
# 123	趻踔
# 123	踸踔
# 124	蔥蘢
# 124	蘢蔥
# 125	嵳峩
# 125	嵯峨
# 126	燾傲
# 126	燾奡
# 127	稠磝
# 127	稠嶅
# 128	蹀躞
# 128	躞蹀
# 129	汎瀾
# 129	氾瀾
# 129	范瀾
# 129	泛瀾
# 130	雰氳
# 130	氛氳
# 131	滑稽
# 131	汩稽
# 132	皓溔
# 132	浩溔
# 132	灝溔
# 133	渾沌
# 133	混沌
# 134	嶢嶭
# 134	嶕嶢
# 135	叫條
# 135	窌條
# 136	跼蹙
# 136	局促
# 136	侷促
# 137	慷慨
# 137	忼慨
# 138	空洞
# 138	空同
# 138	崆峒
# 139	倥傯
# 139	倥偬
# 140	蘭單
# 140	闌單
# 141	闌干
# 141	欄杆
# 142	啷噹
# 142	琅當
# 143	磊塊
# 143	壘塊
# 144	戀眷
# 144	眷戀
# 145	寥唳
# 145	寥戾
# 146	裂缺
# 146	列缺
# 147	璘彬
# 147	瞵彬
# 148	轥轢
# 148	蹸轢
# 148	躪轢
# 149	隆穹
# 149	穹隆
# 150	漭漾
# 150	莽漾
# 151	磅礡
# 151	磅唐
# 151	磅礴
# 152	噴薄
# 152	濆薄
# 152	濆礴
# 153	嫖姚
# 153	飄搖
# 154	縹緲
# 154	瞟眇
# 155	陂阤
# 155	陂陀
# 156	崎嶷
# 156	岐嶷
# 157	磧礫
# 157	磧歷
# 158	蜷跼
# 158	蜷局
# 159	容與
# 159	溶與
# 160	岧嵽
# 160	岹嶤
# 160	岹嵽
# 160	岧嶤
# 161	巍峨
# 161	巍峩
# 162	嗚乎
# 162	烏呼
# 162	嗚虖
# 162	嗚呼
# 162	烏虖
# 162	烏乎
# 163	屭奰
# 163	屓奰
# 164	瀟灑
# 164	蕭灑
# 165	瀟瑟
# 165	蕭瑟
# 166	蕭森
# 166	瀟森
# 167	蕭率
# 167	瀟率
# 168	瀟索
# 168	蕭索
# 169	蕭條
# 169	瀟條
# 170	窅眇
# 170	杳眇
# 171	嶪峨
# 171	嶫峨
# 171	嶪峩
# 172	蘙蔚
# 172	蘙薈
# 173	屹崒
# 173	屹崪
# 174	鬱悒
# 174	蔚結
# 175	輾轉
# 175	展轉
# 176	征營
# 176	正營
# 177	岝崿
# 177	岞崿
