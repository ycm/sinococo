# %% [markdown]
# use `create_ParseDict.ipynb` for this purpose.

# %%
from database import *

# %%
db = load_database()

# %%
db
# Out:
# {'⻖': [('⿰丨㇌', <Node '⿰' with 2 children>)],
#  '㐀': [('⿱卝一', <Node '⿱' with 2 children>)],
#  '㐁': [('⿻𠆣囗', <Node '⿻' with 2 children>)],
#  '㐂': [('⿱七⿰七七', <Node '⿱' with 2 children>)],
#  '㐃': [('⿱人丅', <Node '⿱' with 2 children>)],
#  '㐄': [('⿻十丄', <Node '⿻' with 2 children>),
#   ('⿻十𠃋', <Node '⿻' with 2 children>)],
#  '㐅': [('⿻丿丶', <Node '⿻' with 2 children>)],
#  '㐆': [('⿸𠂆⿱彐𠃌', <Node '⿸' with 2 children>)],
#  '㐇': [('⿱九乙', <Node '⿱' with 2 children>)],
#  '㐈': [('⿱人乙', <Node '⿱' with 2 children>)],
#  '㐉': [('⿱丁乙', <Node '⿱' with 2 children>)],
#  '㐊': [('⿱士乙', <Node '⿱' with 2 children>)],
#  '㐋': [('⿱土乙', <Node '⿱' with 2 children>)],
#  '㐌': [('⿱𠂉也', <Node '⿱' with 2 children>)],
#  '㐍': [('⿱爪乙', <Node '⿱' with 2 children>)],
#  '㐎': [('⿱文乙', <Node '⿱' with 2 children>)],
#  '㐏': [('⿱五乙', <Node '⿱' with 2 children>)],
#  '㐐': [('⿱奴乙', <Node '⿱' with 2 children>)],
#  '㐑': [('⿱冬乙', <Node '⿱' with 2 children>)],
#  '㐒': [('⿱召乙', <Node '⿱' with 2 children>)],
# ...
