# %%
import numpy as np
import pandas as pd
import pickle as pkl
from collections import defaultdict

# %%
df = pd.read_excel('chideod.xlsx')

# %%
def filter_for_gestalt_binomes(row):
    if row.data_source == 'Kroll':
        if len(row.traditional) == 2:
            if row.traditional[0] != row.traditional[1]:
                return True
    return False

# %%
binomes_df = df[df.apply(filter_for_gestalt_binomes, axis=1)]

# %%
binomes_df_clean = binomes_df[['traditional', 'pinyin_tonenumber', 'orthographic_variants']]\
    .drop_duplicates()\
    .sort_values('pinyin_tonenumber')

binomes_df_clean.to_csv('binomes_df.tsv', sep='\t', index=None)

# %%
print(f'{len(binomes_df_clean)} total Gestalt binome entries found.')
binomes_df_clean.head()
# Out:
# 927 total Gestalt binome entries found.
#       traditional pinyin_tonenumber orthographic_variants
# 9494           欸乃          ai3~nai3                   NaN
# 10164          靉靆          ai4~dai4                   NaN
# 9941           薆薱          ai4~dui4                   NaN
# 10162          靉靅          ai4~pei4                   NaN
# 6759           啽囈           an1~yi4                   NaN

# %%
pinyin_to_binomes = defaultdict(set)
for _, row in binomes_df_clean.iterrows():
    pinyin_to_binomes[row.pinyin_tonenumber].add(row.traditional)
    if isinstance(row.orthographic_variants, str):
        variants_str = row.orthographic_variants
        variants_str = variants_str.replace(', ', '|').replace('、', '|').replace(',', '|').replace(' ', '')
        assert all(len(var) == 2 for var in variants_str.split('|')), row.orthographic_variants
        
        for var in variants_str.split('|'):
            pinyin_to_binomes[row.pinyin_tonenumber].add(var)

# %%
words_with_multiple_forms = {k: v for k, v in pinyin_to_binomes.items() if len(v) > 1}
print(f'{len(words_with_multiple_forms)} distinct 2-syllable pronunciations have multiple written forms.')
# Out:
# 209 distinct 2-syllable pronunciations have multiple written forms.

# %%
words_with_multiple_forms
# Out:
# {'an4~tan3': {'黮䨴', '黮暗', '黮黮', '黯黮'},
#  'bi4~fei4': {'蔽芾', '觱沸'},
#  'bi4~yi4': {'辟易', '避易'},
#  'bo2~ran2': {'勃如', '勃然'},
#  'can1~tan2': {'參潭', '參驔'},
#  'cang1~cu4': {'倉卒', '倉猝'},
#  'cang1~huang2': {'倉煌', '倉皇', '蒼黃'},
#  'cang2~cui1': {'摧藏', '藏催'},
#  'cao2~za2': {'嘈囋', '嘈雜'},
#  'cha1~ya2': {'杈枒', '枒杈'},
#  'chai4~jie4': {'蠆介', '蠆芥'},
#  'chan2~juan1': {'嬋娟', '蟬娟'},
#  'chan2~lian2': {'蟬聯', '蟬連'},
#  'chan2~yan2': {'孱顏', '嶄巖', '嶄巗', '巉巖'},
#  'chan2~yuan2': {'嬋媛', '潺湲', '蟬媛'},
#  'chang1~jue2': {'猖獗', '猖蹶'},
#  'chang2~yang2': {'倘佯', '彷徉', '徜徉'},
#  'chang3~huang3': {'惝怳', '惝恍', '敞怳'},
#  'chen3~chuo1': {'趻踔', '踸踔'},
#  'chuo4~yue1': {'汋約', '淖約', '綽約'},
#  'ci1~chi2': {'差池', '柴池'},
#  'cu4~ran2': {'蹙然', '蹴然'},
#  'cui4~cai4': {'綷粲', '綷縩'},
#  'cuo2~e2': {'嵯峨', '嵳峩'},
#  'dan4~man4': {'壇曼', '壇漫'},
#  'dang4~tu2': {'唐突', '碭突'},
#  'dao4~ao4': {'燾傲', '燾奡'},
#  'di4~li4': {'玓瓑', '的皪'},
#  'diao4~ao2': {'稠嶅', '稠磝'},
#  'die1~dang4': {'跌宕', '跌蕩'},
#  'die2~xie4': {'蹀躞', '躞蹀'},
#  'e1~nuo3': {'娜婀', '婀娜'},
#  'e2~ran2': {'峨然', '峩然'},
#  'e3~nuo2': {'猗儺', '猗狔'},
#  'fan1~ran2': {'幡然', '旛然'},
#  'fan4~lan2': {'氾瀾', '汎瀾', '泛瀾', '范瀾'},
#  'fang3~fu2': {'仿佛', '彷彿'},
#  'fei4~wei4': {'怫愄', '沸渭'},
#  'fen1~yun1': {'氛氳', '芬氳', '雰氳'},
#  'fu2~yu4': {'岪鬱', '怫鬱', '茀鬱'},
#  'gu3~ji1': {'汩稽', '滑稽'},
#  'hao4~han4': {'浩汗', '浩瀚', '滈瀚'},
#  'hao4~yao3': {'浩溔', '灝溔', '皓溔'},
#  'hong2~hong2': {'泓宏', '泓汯'},
#  'hong4~dong4': {'港洞', '澒洞'},
#  'hu1~huang3': {'怳惚', '恍惚', '惚怳', '惚恍', '芒忽', '荒忽'},
#  'huang3~hu1': {'恍忽', '恍惚', '慌惚'},
#  'huang4~ran2': {'滉然', '潢然'},
#  'hun2~lun2': {'昆侖', '渾淪'},
#  'hun4~dun4': {'混沌', '渾沌'},
#  'huo4~luo4': {'濩落', '瓠落', '豁落'},
#  'jiao1~yao2': {'嶕嶢', '嶢嶭'},
#  'jiao3~liao3': {'摎蓼', '糾蓼'},
#  'jiao4~tiao2': {'叫條', '窌條'},
#  'jiu1~liu3': {'摎蓼', '糾蓼'},
#  'ju2~cu4': {'侷促', '局促', '跼蹙'},
#  'ju3~lü3': {'痀僂', '踽僂'},
#  'ju3~yu3': {'岨峿', '鉏鋙', '齟齬'},
#  'kan3~ke3': {'坎坷', '坎軻', '轗軻'},
#  'kang1~kai3': {'忼慨', '慷慨'},
#  'kong1~tong2': {'倥侗', '崆峒', '空同', '空洞'},
#  'kong3~zong3': {'倥偬', '倥傯'},
#  'kou4~mao4': {'區霿', '怐愗', '溝瞀'},
#  'lan2~dan1': {'蘭單', '闌單'},
#  'lan2~gan1': {'欄杆', '闌干'},
#  'lan2~lü3': {'藍縷', '藍褸', '襤褸'},
#  'lang2~dang1': {'啷噹', '琅當'},
#  'lei3~kuai4': {'壘塊', '磊塊'},
#  'li2~shi1': {'褵褷', '褷褵'},
#  'li3~yi3': {'迤邐', '邐迤'},
#  'lian2~quan2': {'聯卷', '連卷'},
#  'lian4~juan4': {'戀眷', '眷戀'},
#  'liang4~qiang1': {'踉蹌', '踉蹡'},
#  'liao2~li4': {'嘹唳', '寥唳', '寥戾', '漻浰', '飂戾', '飉濿'},
#  'liao2~liang4': {'嘹亮', '寥亮'},
#  'lie4~que1': {'列缺', '裂缺'},
#  'lin2~bin1': {'璘彬', '瞵彬'},
#  'lin2~li2': {'淋灕', '綝纚'},
#  'lin2~li4': {'惏悷', '轔轢'},
#  'lin4~li4': {'蹸轢', '躪轢', '轔轢', '轥轢'},
#  'ling2~hong1': {'岺巆', '輘輷'},
#  'ling2~li4': {'凌厲', '凌歷'},
#  'ling2~luo4': {'苓落', '零落'},
#  'ling2~ping1': {'伶俜', '俜伶'},
#  'ling2~qing2': {'㱥殑', '殑㱥'},
#  'liu2~qiu2': {'䚧觩', '蟉虯'},
#  'long2~qiong2': {'穹隆', '隆穹'},
#  'long3~cong1': {'蔥蘢', '蘢蔥'},
#  'mai4~mu4': {'霡霂', '霢霂'},
#  'mang3~yang4': {'漭漾', '莽漾'},
#  'mi2~man4': {'彌漫', '瀰漫'},
#  'ming3~xing4': {'涬溟', '溟涬'},
#  'nao2~tiao1': {'撓挑', '橈橈'},
#  'nie4~wu4': {'杌隉', '蘖卼', '阢隉'},
#  'pai2~huai2': {'徘徊', '裴徊'},
#  'pan2~bi4': {'媻姍', '媻珊', '磐辟', '蹣辟'},
#  'pan2~bo2': {'槃礡', '盤薄', '磐礡', '磐薄'},
#  'pan2~huan2': {'盤桓', '磐桓'},
#  'pan2~lian2': {'媻姍', '媻珊', '蹣連'},
#  'pan2~shan1': {'媻姍', '媻珊', '蹣跚'},
#  'pan4~huan4': {'判換', '叛換'},
#  'pang2~bo2': {'旁魄', '磅唐', '磅礴'},
#  'pang2~huang2': {'傍偟', '徬徨'},
#  'pang2~tang2': {'磅唐', '磅礴'},
#  'pang2~yang2': {'倘佯', '彷徉', '徜徉'},
#  'pao2~xiao1': {'咆哮', '炰烋'},
#  'pei2~huai2': {'徘徊', '裴徊'},
#  'pen1~bo2': {'噴薄', '濆礴', '濆薄'},
#  'peng1~pai4': {'淜湃', '澎湃'},
#  'pi3~ni2': {'俾倪', '埤坭'},
#  'pi4~ni4': {'俾倪', '埤坭', '埤堄', '睥睨'},
#  'piao1~yao2': {'嫖姚', '飄搖'},
#  'piao3~miao3': {'瞟眇', '縹緲'},
#  'pie1~lie4': {'瞥列', '瞥裂'},
#  'po1~tuo2': {'坡坨', '陂阤', '陂陀'},
#  'po2~suo1': {'婆娑', '媻娑'},
#  'pu2~fu2': {'匍匐', '葡伏', '葡服'},
#  'qi1~cao3': {'戚促', '戚草'},
#  'qi1~cu4': {'戚促', '戚草'},
#  'qi2~yi2': {'岐嶷', '崎嶷'},
#  'qi4~li4': {'磧歷', '磧礫'},
#  'qian1~mian2': {'芊眠', '芊綿', '芊芊', '阡眠', '阡綿'},
#  'qiang1~ling2': {'瑲玲', '鎗玲'},
#  'qiao2~cui4': {'憔悴', '憔顇', '譙譙'},
#  'qin1~yin2': {'浸淫', '浸潯'},
#  'quan2~ju2': {'蜷局', '蜷跼'},
#  'qun1~xun2': {'逡巡', '逡循'},
#  'ran3~ren3': {'苒荏', '荏苒'},
#  'ren3~ran3': {'苒荏', '荏苒'},
#  'rong2~yu3': {'容與', '溶與'},
#  'shao2~yao2': {'招搖', '逍遙'},
#  'shi1~li2': {'褵褷', '褷褵'},
#  'shu1~hu1': {'倏忽', '儵忽'},
#  'tan1~dan4': {'舑舕', '舔舕'},
#  'tan3~an4': {'黮䨴', '黮暗', '黮黮', '黯黮'},
#  'tan3~dui4': {'黮䨴', '黮暗', '黮黮', '黯黮'},
#  'tang2~tu1': {'唐突', '樘突'},
#  'tang3~lang3': {'儻朗', '儻閬', '曭朗', '爣朗', '爣閬'},
#  'ti4~tang3': {'俶儻', '倜儻'},
#  'tian3~tan4': {'舑舕', '舔舕'},
#  'tiao2~di4': {'岧岧', '岧嵽', '岧嶤', '岹岹', '岹嵽', '岹嶤', '迢遞'},
#  'tiao2~yao2': {'岧岧', '岧嵽', '岧嶤', '岹岹', '岹嵽', '岹嶤'},
#  'ting3~tuan3': {'町畽', '町疃'},
#  'tong2~long2': {'曈曈', '曈曚', '曈曨', '膧䑃', '膧朧'},
#  'tong2~meng2': {'曈曈', '曈曚', '曈曨', '氃氋', '瞳矇', '膧䑃', '膧朧'},
#  'tu1~wu4': {'秃兀', '突兀'},
#  'wan1~yan2': {'蜿蜒', '蜿蜿'},
#  'wan2~lan2': {'汍瀾', '汍蘭'},
#  'wang1~xiang2': {'望洋', '汪洋', '汪漾', '汪翔'},
#  'wang1~yang2': {'望洋', '汪洋', '汪漾', '汪翔'},
#  'wang1~yang4': {'汪洋', '汪漾', '汪翔', '瀇漾'},
#  'wang3~yang4': {'汪漾', '瀇漾', '瀇瀁'},
#  'wang4~yang2': {'望洋', '汪洋', '汪漾', '汪翔'},
#  'wei1~rui2': {'萎蕤', '葳蕤'},
#  'wei2~e2': {'嵬嵬', '巍峨', '巍峩', '巍巍'},
#  'wo4~chuo4': {'握齱', '齷齪'},
#  'wu1~hu1': {'嗚乎', '嗚呼', '嗚虖', '烏乎', '烏呼', '烏虖'},
#  'wu4~nie4': {'杌隉', '蘖卼', '阢隉'},
#  'xi1~huang2': {'恓屑', '恓恓', '恓惶'},
#  'xi1~xian3': {'巇險', '險巇'},
#  'xi1~xiang4': {'肸肸', '肸蠁'},
#  'xi1~xie4': {'恓屑', '恓恓', '恓惶', '棲屑'},
#  'xi4~bi4': {'屓奰', '屭奰'},
#  'xia2~die2': {'浹渫', '渫渫'},
#  'xian3~xi1': {'巇險', '險巇'},
#  'xiang1~yang2': {'儴佯', '忀徉', '相羊'},
#  'xiao1~sa3': {'瀟灑', '蕭灑'},
#  'xiao1~se4': {'瀟瑟', '蕭瑟'},
#  'xiao1~sen1': {'瀟森', '蕭森'},
#  'xiao1~shuai4': {'瀟率', '蕭率'},
#  'xiao1~suo3': {'瀟索', '蕭索'},
#  'xiao1~tiao2': {'瀟條', '蕭條'},
#  'xiao1~yao2': {'招搖', '逍遙'},
#  'xiao3~yao3': {'皛溔', '皛皛'},
#  'xie4~die2': {'蹀躞', '躞蹀'},
#  'xing1~song1': {'惺忪', '惺鬆'},
#  'xu1~xi1': {'歔欷', '歘吸'},
#  'ya1~cha1': {'杈枒', '枒杈'},
#  'yan1~ran2': {'嫣然', '閹然'},
#  'yang3~ya4': {'坱圠', '坱軋'},
#  'yao2~e4': {'嶕嶢', '嶢嶭'},
#  'yao3~miao3': {'杳眇', '窅眇'},
#  'yao3~tiao3': {'䆗窱', '窈窕'},
#  'yao4~miao4': {'幼妙', '幼眇'},
#  'ye4~e2': {'嶪峨', '嶪峩', '嶪嶪', '嶫峨', '嶫嶫'},
#  'yi3~li3': {'迤邐', '邐迤'},
#  'yi3~ni3': {'旖旎', '猗儺', '猗狔'},
#  'yi4~hui4': {'蘙蔚', '蘙薈'},
#  'yi4~wei4': {'蘙蔚', '蘙薈'},
#  'yi4~yu4': {'佚豫', '抑鬱'},
#  'yi4~zu2': {'屹崒', '屹崪'},
#  'yin1~qin2': {'慇勤', '慇懃', '殷勤'},
#  'yin1~xun2': {'因巡', '因循'},
#  'yin1~yun1': {'氤氳', '烟熅', '絪縕', '茵蒀'},
#  'yong2~ran2': {'喁喁', '顒然', '顒顒'},
#  'you1~rou2': {'優柔', '優遊'},
#  'you1~you2': {'優柔', '優游', '優遊'},
#  'yu2~ran2': {'俞俞', '俞然'},
#  'yu4~jie2': {'蔚結', '蔚蔚', '鬱悒', '鬱鬱'},
#  'yu4~yi4': {'蔚結', '蔚蔚', '鬱悒', '鬱鬱'},
#  'zhan1~zhun1': {'迍邅', '邅迍'},
#  'zhan3~ran2': {'嶄然', '蹍然'},
#  'zhan3~zhuan3': {'展轉', '輾轉'},
#  'zheng1~ying2': {'征營', '正營'},
#  'zhou1~jiao1': {'啁啾', '啁噍'},
#  'zhou1~zhang1': {'侜張', '譸張', '輈張'},
#  'zhun1~zhan1': {'迍邅', '邅迍'},
#  'zhuo2~ran2': {'灼然', '酌然'},
#  'zuo2~e4': {'岝崿', '岞崿'}}

# %%
with open('df_full_5y.pkl', 'rb') as f:
    ngram_df = pkl.load(f)

# %%
all_recorded_terms = set(ngram_df.term)

all_binomes = {binome for _, binomes in pinyin_to_binomes.items() for binome in binomes}

print(f'Out of {len(all_binomes)} binomes and {len(all_recorded_terms)} terms recorded in Google Ngrams, {len(all_binomes & all_recorded_terms)} of the binomes appear in Google Ngrams.')
# Out:
# Out of 981 binomes and 95220 terms recorded in Google Ngrams, 65 of the binomes appear in Google Ngrams.

# %%
all_binomes & all_recorded_terms
# Out:
# {'仿佛',
#  '侏儒',
#  '依稀',
#  '充斥',
#  '勃然',
#  '匍匐',
#  '呻吟',
#  '咀嚼',
#  '咆哮',
#  '咫尺',
#  '唐突',
#  '因循',
#  '坎坷',
#  '妥帖',
#  '孟浪',
#  '局促',
#  '巍峨',
#  '差池',
#  '幡然',
#  '徘徊',
#  '徜徉',
#  '恍惚',
#  '慷慨',
#  '憔悴',
#  '憧憬',
#  '披靡',
#  '拮据',
#  '揶揄',
#  '放浪',
#  '斟酌',
#  '旖旎',
#  '梗概',
#  '模糊',
#  '殷勤',
#  '汪洋',
#  '油然',
#  '浩瀚',
#  '浸淫',
#  '混沌',
#  '渺茫',
#  '滑稽',
#  '潦倒',
#  '澎湃',
#  '猖狂',
#  '猖獗',
#  '璀璨',
#  '磅礴',
#  '磊落',
#  '穹隆',
#  '空洞',
#  '突兀',
#  '索然',
#  '翠微',
#  '翱翔',
#  '芳菲',
#  '茫然',
#  '荒唐',
#  '蓬勃',
#  '蜿蜒',
#  '跌宕',
#  '蹉跎',
#  '邂逅',
#  '雍容',
#  '零落',
#  '鞠躬'}
